# %%
#Dataframe creation by Crystal Butler
#import in cleaned song dataset created from "Explore_data.ipynb"
import pandas as pd
csv_data = "dupl_removed_final3.csv"

# %%
#create music df
music_df = pd.read_csv(csv_data)

# %%
#view music df
music_df.head()
# Out:
#   artist_names          track_name  rank  weeks_on_chart  streams  \
# 0         SyKo  #BrooklynBloodPop!   189               2     6046
# 1         SyKo  #BrooklynBloodPop!    79               1     7204
# 2         SyKo  #BrooklynBloodPop!    54               2     9060
# 3         SyKo  #BrooklynBloodPop!    71               3     8243
# 4         SyKo  #BrooklynBloodPop!   108               4     7515
#
#    danceability  energy  loudness  speechiness  acousticness  valence  \
# 0         0.691   0.814    -3.788        0.117        0.0164    0.509
# 1         0.691   0.814    -3.788        0.117        0.0164    0.509
# 2         0.691   0.814    -3.788        0.117        0.0164    0.509
# 3         0.691   0.814    -3.788        0.117        0.0164    0.509
# 4         0.691   0.814    -3.788        0.117        0.0164    0.509
#
#      tempo  duration   country
# 0  132.012       146  Bulgaria
# 1  132.012       146   Estonia
# 2  132.012       146   Estonia
# 3  132.012       146   Estonia
# 4  132.012       146   Estonia

# %%
# this will replace "United States" with "United States of America" and "Hong Kong" with "China"
music_df = music_df.replace(to_replace="United States",
           value="United States of America")
music_df = music_df.replace(to_replace="Hong Kong",
           value="China")

# %%
#create groupby data for countries attributes df
countries_data = music_df.groupby(music_df['country'])['danceability', 'energy','loudness',
       'speechiness', 'acousticness','valence', 'tempo', 'duration'].mean()
# Out:
# C:\Users\cmbut\AppData\Local\Temp\ipykernel_35192\1645244883.py:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   countries_data = music_df.groupby(music_df['country'])['danceability', 'energy','loudness',

# %%
#create countries attrib df and reset index
countries_attrib_df = pd.DataFrame(countries_data).sort_values(['country']).round(2)
countries_attrib_df = countries_attrib_df.reset_index()
countries_attrib_df.head(5)
# Out:
#      country  danceability  energy  loudness  speechiness  acousticness  \
# 0  Argentina          0.74    0.68     -5.22         0.13          0.23
# 1  Australia          0.65    0.63     -6.48         0.10          0.25
# 2    Austria          0.69    0.67     -6.32         0.11          0.21
# 3    Belarus          0.69    0.66     -7.13         0.13          0.21
# 4    Belgium          0.70    0.68     -6.20         0.11          0.22
#
#    valence   tempo  duration
# 0     0.65  120.36    206.66
# 1     0.50  120.49    210.16
# 2     0.53  123.42    187.42
# 3     0.46  124.35    171.49
# 4     0.55  122.50    197.81

# %%
#create countries list to be used to create another countries top 50 df
countries = []
countries = [column for column in countries_attrib_df['country']]
print(countries)
# Out:
# ['Argentina', 'Australia', 'Austria', 'Belarus', 'Belgium', 'Bolivia', 'Brazil', 'Bulgaria', 'Canada', 'Chile', 'China', 'Colombia', 'Costa Rica', 'Cyprus', 'Czech Republic', 'Denmark', 'Dominican Republic', 'Ecuador', 'Egypt', 'El Salvador', 'Estonia', 'Finland', 'France', 'Germany', 'Greece', 'Guatemala', 'Honduras', 'Hungary', 'Iceland', 'India', 'Indonesia', 'Ireland', 'Israel', 'Italy', 'Japan', 'Kazakhstan', 'Korea', 'Latvia', 'Lithuania', 'Luxembourg', 'Malaysia', 'Mexico', 'Morocco', 'Netherlands', 'New Zealand', 'Nicaragua', 'Nigeria', 'Norway', 'Pakistan', 'Panama', 'Paraguay', 'Peru', 'Philippines', 'Poland', 'Portugal', 'Romania', 'Saudi Arabia', 'Singapore', 'Slovakia', 'South Africa', 'Spain', 'Sweden', 'Switzerland', 'Taiwan', 'Thailand', 'Turkey', 'Ukraine', 'United Arab Emirates', 'United Kingdom', 'United States of America', 'Uruguay', 'Venezuela', 'Vietnam']

# %%
#bring in artists_genre csv from dataset created from "Explore_data.ipynb"
csv_data2 = "artist_genres.csv"
genre_df = pd.read_csv(csv_data2)
genre_df.head(5)
# Out:
#                            artist_names    artist_genre
# 0                  Bad Bunny, Tony Dize   latin hip hop
# 1  Blessd, Justin Quiles, Lenny Tavárez       reggaeton
# 2  Blessd, Justin Quiles, Lenny Tavárez       reggaeton
# 3  Blessd, Justin Quiles, Lenny Tavárez  reggaeton flow
# 4          Eladio Carrion, Nicki Nicole     trap triste

# %%
#create genre dataframe from the csv
genre_df = genre_df.loc[genre_df['artist_genre'] != '0']

# %%
#aggregate instances of genres across the dataframe 
most_pop_genres_df = pd.DataFrame(genre_df.groupby(genre_df['artist_genre']).count())
most_pop_genres_df = most_pop_genres_df.sort_values(['artist_names'], ascending=False)
#just keep the top 50 genres
top_fifty_genres_df = most_pop_genres_df.head(50)

top_fifty_genres_df.head(5)
# Out:
#               artist_names
# artist_genre
# pop                 107610
# trap latino          40392
# latin                34474
# reggaeton            33662
# dance pop            31377

# %%
top_fifty_genres_df = top_fifty_genres_df.reset_index()
top_fifty_genres_df
# Out:
#                  artist_genre  artist_names
# 0                         pop        107610
# 1                 trap latino         40392
# 2                       latin         34474
# 3                   reggaeton         33662
# 4                   dance pop         31377
# 5                         rap         19871
# 6                      uk pop         17790
# 7                       k-pop         15272
# 8                canadian pop         14007
# 9                     hip hop          9630
# 10       reggaeton colombiano          8903
# 11                    pop rap          8743
# 12             german hip hop          8521
# 13                       trap          8477
# 14                  latin pop          8472
# 15                  pop dance          7472
# 16                melodic rap          7364
# 17             tropical house          6754
# 18                chicago rap          6380
# 19            k-pop boy group          6323
# 20  canadian contemporary r&b          6282
# 21              latin hip hop          6246
# 22                      j-pop          6231
# 23         australian hip hop          6224
# 24                israeli pop          6030
# 25             trap argentino          5795
# 26                        edm          5748
# 27             reggaeton flow          5743
# 28                        r&b          5698
# 29           puerto rican pop          5697
# 30                   cantopop          5617
# 31                modern rock          5536
# 32                 danish pop          5384
# 33                   mandopop          5326
# 34                 greek trap          5243
# 35             indonesian pop          5126
# 36                    arrocha          5052
# 37             brooklyn drill          4974
# 38                 electropop          4889
# 39                italian pop          4853
# 40            russian hip hop          4566
# 41                       rock          4513
# 42                   thai pop          4431
# 43                 slap house          4414
# 44                  dutch pop          4376
# 45              post-teen pop          4375
# 46             polish hip hop          4142
# 47           egyptian hip hop          4046
# 48             lgbtq+ hip hop          4038
# 49              colombian pop          4001

# %%
music_df.columns
# Out:
# Index(['artist_names', 'track_name', 'rank', 'weeks_on_chart', 'streams',
#        'danceability', 'energy', 'loudness', 'speechiness', 'acousticness',
#        'valence', 'tempo', 'duration', 'country'],
#       dtype='object')

# %%
#find the average rank and number of streams of each song and artist combo
aver_rank_streams = music_df.groupby(['artist_names','track_name'])['rank','streams'].mean().round(0)
aver_rank_streams_df = pd.DataFrame(aver_rank_streams)

aver_rank_streams_df.head(5)
# Out:
# C:\Users\cmbut\AppData\Local\Temp\ipykernel_35192\1197850940.py:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   aver_rank_streams = music_df.groupby(['artist_names','track_name'])['rank','streams'].mean().round(0)
#                                                                                rank  \
# artist_names                      track_name
# #TocoParaVos, El Reja, Marka Akme Se Picó                                      94.0
# $NOT                              GOSHA                                       155.0
# $NOT, A$AP Rocky                  Doja                                        108.0
# $NOT, Lil Skies, Internet Money   Whipski (feat. Lil Skies & Internet Money)  138.0
# $OHO BANI                         VIRAL                                       138.0
#
#                                                                                streams
# artist_names                      track_name
# #TocoParaVos, El Reja, Marka Akme Se Picó                                     137573.0
# $NOT                              GOSHA                                         5724.0
# $NOT, A$AP Rocky                  Doja                                        242309.0
# $NOT, Lil Skies, Internet Money   Whipski (feat. Lil Skies & Internet Money)  440500.0
# $OHO BANI                         VIRAL                                       398532.0

# %%
#reset index
aver_rank_streams_df = aver_rank_streams_df.reset_index()
aver_rank_streams_df = aver_rank_streams_df[['artist_names','track_name','rank','streams']]
aver_rank_streams_df.head(5)
# Out:
#                         artist_names  \
# 0  #TocoParaVos, El Reja, Marka Akme
# 1                               $NOT
# 2                   $NOT, A$AP Rocky
# 3    $NOT, Lil Skies, Internet Money
# 4                          $OHO BANI
#
#                                    track_name   rank   streams
# 0                                     Se Picó   94.0  137573.0
# 1                                       GOSHA  155.0    5724.0
# 2                                        Doja  108.0  242309.0
# 3  Whipski (feat. Lil Skies & Internet Money)  138.0  440500.0
# 4                                       VIRAL  138.0  398532.0

# %%
#get max weeks on chart and convert to dataframe, reset index
max_weeks_on_chart = music_df.groupby(['artist_names','track_name'])['weeks_on_chart'].max()
max_weeks_on_chart_df = pd.DataFrame(max_weeks_on_chart).sort_values(['weeks_on_chart'], ascending=False)
max_weeks_on_chart_df = max_weeks_on_chart_df.reset_index()

# %%
max_weeks_on_chart_df.columns
# Out:
# Index(['artist_names', 'track_name', 'weeks_on_chart'], dtype='object')

# %%
#create coolness dataframe by merging max weeks and aver rank streams dataframes
coolness_df = pd.merge(max_weeks_on_chart_df,aver_rank_streams_df,how='left',left_on=['artist_names','track_name'],right_on=['artist_names','track_name'])

# %%
#create a Weeks on Chart ratio to get a value to calculate popularity and add as a column to coolness df
coolness_df['WOC_ratio'] = coolness_df['weeks_on_chart'].div(290).round(3)
coolness_df.head(5)
# Out:
#                                         artist_names            track_name  \
# 0                                         Ed Sheeran            Photograph
# 1                                          Hebe Tien                   小幸運
# 2  Anuel AA, Daddy Yankee, Zion & Lennox, Farruko...          Sola (Remix)
# 3                                       James Arthur  Say You Won't Let Go
# 4                                       South Border               Rainbow
#
#    weeks_on_chart   rank   streams  WOC_ratio
# 0             290  147.0  130715.0        1.0
# 1             290  108.0   54015.0        1.0
# 2             290  137.0   45522.0        1.0
# 3             290  124.0  163759.0        1.0
# 4             290   78.0  386851.0        1.0

# %%
#find max rank
coolness_df['rank'].max()
# Out:
# 200.0

# %%
#iterate through rank values and create "rank pts" to get a value to calculate popularity
rank_pts = []
for row in coolness_df['rank']:
    rank_pts.append((100 - (row * .5))/100)

# %%
#add rank pts to dataframe
coolness_df['rank_pts'] = rank_pts

# %%
#cheaking rank pts values
coolness_df.sort_values(['rank_pts'],ascending=False).head(5)
# Out:
#                        artist_names track_name  weeks_on_chart  rank  \
# 12067         Abdul Hannan, Rovalio     Bikhra              10   1.0
# 11683                      Keung To      作品的說話              11   1.0
# 15028  V:RGO, EMIL TRF, FYRE, 2bona    PARALIA               6   1.0
# 20985                     Formalite  Mahvettim               2   1.0
# 23073                        j-hope   Airplane               1   1.0
#
#         streams  WOC_ratio  rank_pts
# 12067  203875.0      0.034     0.995
# 11683  285090.0      0.038     0.995
# 15028   48896.0      0.021     0.995
# 20985   23120.0      0.007     0.995
# 23073  454813.0      0.003     0.995

# %%
#create streams ratio and add to dataframe, so we can calculate popularity
coolness_df['streams_ratio'] = coolness_df['streams'].div(4026918).round(3)
coolness_df.sort_values(['streams_ratio'],ascending=False).head(5)
# Out:
#              artist_names                 track_name  weeks_on_chart  rank  \
# 8862                Tulus         Hati-Hati di Jalan              19   9.0
# 12506          João Gomes                      Dengo              10  20.0
# 13642     Keisya Levronka             Tak Ingin Usai               8   3.0
# 4292   Henrique & Juliano  A Maior Saudade - Ao Vivo              45  19.0
# 12269      Jorge & Mateus         Todo Seu - Ao Vivo              10  18.0
#
#          streams  WOC_ratio  rank_pts  streams_ratio
# 8862   4026918.0      0.066     0.955          1.000
# 12506  4025622.0      0.034     0.900          1.000
# 13642  3624225.0      0.028     0.985          0.900
# 4292   3549891.0      0.155     0.905          0.882
# 12269  3496942.0      0.034     0.910          0.868

# %%
#create a popularity score that averages the WOC ratio, rank pts, and streams ratio
coolness_df['Popularity_Score'] = (coolness_df['WOC_ratio'] + coolness_df['rank_pts'] + coolness_df['streams_ratio'])/3

# %%
#sort Popularity score to see highest values.. helps find "most popular" song
coolness_df = coolness_df.sort_values(['Popularity_Score'],ascending=False)
coolness_df.head(5)
# Out:
#              artist_names                 track_name  weeks_on_chart  rank  \
# 8862                Tulus         Hati-Hati di Jalan              19   9.0
# 4292   Henrique & Juliano  A Maior Saudade - Ao Vivo              45  19.0
# 12506          João Gomes                      Dengo              10  20.0
# 13642     Keisya Levronka             Tak Ingin Usai               8   3.0
# 12269      Jorge & Mateus         Todo Seu - Ao Vivo              10  18.0
#
#          streams  WOC_ratio  rank_pts  streams_ratio  Popularity_Score
# 8862   4026918.0      0.066     0.955          1.000          0.673667
# 4292   3549891.0      0.155     0.905          0.882          0.647333
# 12506  4025622.0      0.034     0.900          1.000          0.644667
# 13642  3624225.0      0.028     0.985          0.900          0.637667
# 12269  3496942.0      0.034     0.910          0.868          0.604000

# %%
usa_df = music_df.loc[music_df['country'] == 'United States of America']
usa_df.head(5)
# Out:
#      artist_names      track_name  rank  weeks_on_chart  streams  \
# 184  Cody Johnson  'Til You Can't   154               1  1556168
# 185  Cody Johnson  'Til You Can't   158               2  1689695
# 186  Cody Johnson  'Til You Can't   151               3  1727287
# 187  Cody Johnson  'Til You Can't   183               4  1576313
# 188  Cody Johnson  'Til You Can't   135               5  1793033
#
#      danceability  energy  loudness  speechiness  acousticness  valence  \
# 184         0.501   0.815    -4.865       0.0436        0.0513     0.46
# 185         0.501   0.815    -4.865       0.0436        0.0513     0.46
# 186         0.501   0.815    -4.865       0.0436        0.0513     0.46
# 187         0.501   0.815    -4.865       0.0436        0.0513     0.46
# 188         0.501   0.815    -4.865       0.0436        0.0513     0.46
#
#        tempo  duration                   country
# 184  160.087       224  United States of America
# 185  160.087       224  United States of America
# 186  160.087       224  United States of America
# 187  160.087       224  United States of America
# 188  160.087       224  United States of America

# %%
usa_df = usa_df.drop_duplicates(subset=['artist_names','track_name'],keep='first')
usa_df = usa_df[['artist_names','track_name','country']]
usa_df.columns = usa_df.columns.str.upper()
usa_df.head(5)
# Out:
#            ARTIST_NAMES                                         TRACK_NAME  \
# 184        Cody Johnson                                     'Til You Can't
# 778   Eminem, Nate Dogg                                   'Till I Collapse
# 799           Kay Starr  (Everybody's Waitin' For) The Man With The Bag...
# 824          Perry Como  (There's No Place Like) Home for the Holidays ...
# 1185        $uicideboy$  ...And to Those I Love, Thanks for Sticking Ar...
#
#                        COUNTRY
# 184   United States of America
# 778   United States of America
# 799   United States of America
# 824   United States of America
# 1185  United States of America

# %%
usa_coolness_df = pd.merge(coolness_df,usa_df,how='inner',left_on=['artist_names','track_name'],right_on=['ARTIST_NAMES','TRACK_NAME'])
usa_coolness_df = usa_coolness_df.sort_values(['Popularity_Score'],ascending=False)
usa_coolness_df.head(5)
# Out:
#     artist_names              track_name  weeks_on_chart   rank    streams  \
# 0    The Killers          Mr. Brightside             290   97.0   591710.0
# 1       Kid Cudi                   love.               1   29.0  3233804.0
# 2  Fleetwood Mac  Dreams - 2004 Remaster             260   96.0   481432.0
# 3        J. Cole          No Role Modelz             277  114.0   305076.0
# 4  Morgan Wallen               You Proof               9   40.0  2442435.0
#
#    WOC_ratio  rank_pts  streams_ratio  Popularity_Score   ARTIST_NAMES  \
# 0      1.000     0.515          0.147          0.554000    The Killers
# 1      0.003     0.855          0.803          0.553667       Kid Cudi
# 2      0.897     0.520          0.120          0.512333  Fleetwood Mac
# 3      0.955     0.430          0.076          0.487000        J. Cole
# 4      0.031     0.800          0.607          0.479333  Morgan Wallen
#
#                TRACK_NAME                   COUNTRY
# 0          Mr. Brightside  United States of America
# 1                   love.  United States of America
# 2  Dreams - 2004 Remaster  United States of America
# 3          No Role Modelz  United States of America
# 4               You Proof  United States of America

# %%
x = usa_coolness_df['weeks_on_chart'].max() 

usa_coolness_df['weeks_on_chart'].div(x).head(5)
# Out:
# 0    1.000000
# 1    0.003448
# 2    0.896552
# 3    0.955172
# 4    0.031034
# Name: weeks_on_chart, dtype: float64

# %%
# applying groupby() function to
# group the data on team value.
gk = music_df.groupby('country')
  
def create_df(country):
    cntry_df = gk.get_group(country)
    song_grpd = cntry_df.groupby(['artist_names','track_name']).aggregate({'streams':'mean','rank':'mean','weeks_on_chart':'max','danceability':'mean', 'energy':'mean','loudness':'mean',
        'speechiness':'mean', 'acousticness':'mean','valence':'mean', 'tempo':'mean', 'duration':'mean'}).round(3)
    song_grpd = song_grpd.reset_index()
    song_grpd['country'] = country
    song_grpd.sort_values(['weeks_on_chart'],ascending=False)
    x= song_grpd['weeks_on_chart'].max()
    song_grpd['WOC_ratio'] = song_grpd['weeks_on_chart'].div(x).round(3)
    song_grpd['rank'].max()
    rank_pts = []
    for row in song_grpd['rank']:
        rank_pts.append((100 - (row * .5))/100)
    song_grpd['rank_pts'] = rank_pts
    song_grpd.sort_values(['streams'],ascending=False)
    y = song_grpd['streams'].max()
    song_grpd['streams_ratio'] = song_grpd['streams'].div(y).round(3)
    song_grpd.sort_values(['streams_ratio'],ascending=False)
    song_grpd['Popularity_Score'] = (song_grpd['WOC_ratio'] + song_grpd['rank_pts'] + song_grpd['streams_ratio'])/3
    song_grpd.columns
    best_songs = song_grpd[['artist_names', 'track_name', 'Popularity_Score', 'WOC_ratio', 'rank_pts',
        'streams_ratio','streams', 'rank', 'weeks_on_chart',
        'danceability', 'energy', 'loudness', 'speechiness', 'acousticness',
        'valence', 'tempo', 'duration','country']]
    best_songs = best_songs.sort_values(['Popularity_Score'],ascending=False)
    top_fifty = best_songs.head(50)
    
    return top_fifty

# %%
first = True
for c in countries:
    country_df = create_df(c)
    if first:
        all_countries_top_fifty_df = country_df
        first = False
    all_countries_top_fifty_df = pd.merge(all_countries_top_fifty_df,country_df, how='outer')

# %%
all_countries_top_fifty_df.columns = all_countries_top_fifty_df.columns.str.upper()
usa_coolness_df.columns = usa_coolness_df.columns.str.upper()
coolness_df.columns = coolness_df.columns.str.upper()
countries_attrib_df.columns = countries_attrib_df.columns.str.upper()
top_fifty_genres_df.columns = top_fifty_genres_df.columns.str.upper()

# %%
first = True
for c in countries:
    country_df = create_df(c)
    if first:
        all_countries_top_fifty_df = country_df
        first = False
    all_countries_top_fifty_df = pd.merge(all_countries_top_fifty_df,country_df, how='outer')

# %%
all_countries_top_fifty_df
#write to a csv 
all_countries_top_fifty_df.to_csv("Resources/all_countries_top_fifty.csv")

# %%
#import all dependencies for Sqlalchemy
# from sqlalchemy import create_engine
import sqlite3

# Import modules to declare columns and column data types
# from sqlalchemy import Column, Integer, String, Float, Boolean

# %%
#create a connect and name the sqlite database for top fifty countries
countries_conn = sqlite3.connect('country_db.sqlite')
print(countries_conn)
all_countries_top_fifty_df.to_sql('countries', countries_conn, if_exists='replace', index=False)
#check if the sqlite is working
all_countries_top_fifty_df = pd.read_sql_query("SELECT * FROM countries", countries_conn)
for countries  in all_countries_top_fifty_df.values:
       print(countries)
# Out:
# <sqlite3.Connection object at 0x000002C2B2D23E40>
# ['Bizarrap, Quevedo' 'Quevedo: Bzrp Music Sessions, Vol. 52'
#  0.6263333333333333 0.014 0.865 1.0 3357665.5 27.0 2 0.621 0.782 -5.548
#  0.044 0.012 0.55 128.033 199.0 'Argentina']
# ['TINI, Maria Becerra' 'Miénteme' 0.6023616666666667 0.429 0.892085 0.486
#  1631911.556 21.583 63 0.85 0.541 -4.522 0.067 0.161 0.916 92.003 165.0
#  'Argentina']
# ['Bad Bunny, Bomba Estéreo' 'Ojitos Lindos' 0.5851116666666666 0.068
#  'Vietnam']
# ['Da LAB, Miu Lê' 'Gác Lại Âu Lo (feat. Miu Lê)' 0.4128333333333334 0.274
#  0.8925 0.072 126093.062 21.5 60 0.745 0.527 -8.09 0.079 0.571 0.385
#  95.034 283.0 'Vietnam']
# ['MONSTAR' 'có hẹn với thanh xuân' 0.40639666666666674 0.219
#  0.9201900000000001 0.08 140547.5 15.962 48 0.613 0.5 -8.349 0.028 0.547
#  0.342 99.998 218.0 'Vietnam']
# ['Vũ.' 'Bước Qua Nhau' 0.4059266666666666 0.142 0.9577800000000001 0.118
#  206944.778 8.444 31 0.541 0.339 -6.499 0.027 0.742 0.215 135.757 258.0
#  'Vietnam']
# ['Alec Benjamin' 'Let Me Down Slowly' 0.40398666666666666 0.89
#  0.30096000000000006 0.021 37468.5 139.808 195 0.652 0.557 -5.714 0.032
#  0.74 0.483 150.073 169.0 'Vietnam']
# ['Joji' 'Glimpse of Us' 0.40199999999999997 0.005 0.975 0.226 396815.0 5.0
#  1 0.44 0.317 -9.258 0.053 0.891 0.268 169.914 233.0 'Vietnam']
# ['Da LAB' 'Thức Giấc' 0.40093833333333334 0.224 0.8998149999999999 0.079
#  138319.963 20.037 49 0.66 0.578 -8.591 0.031 0.45 0.19 127.092 269.0
#  'Vietnam']
# ['dhruv' 'double take' 0.3991383333333334 0.265 0.862415 0.07 122155.552
#  27.517 58 0.614 0.436 -11.152 0.074 0.841 0.208 109.064 172.0 'Vietnam']
# ['BTS' 'Life Goes On' 0.39640666666666674 0.374 0.7622200000000001 0.053
#  93371.5 47.556 82 0.566 0.716 -5.733 0.042 0.007 0.45 81.068 207.0
#  'Vietnam']
# ['Wren Evans' 'Thích Em Hơi Nhiều' 0.3885 0.237 0.8575 0.071 123883.893
#  28.5 52 0.92 0.41 -9.497 0.455 0.372 0.861 143.034 172.0 'Vietnam']
# ['Chillies' 'Và Thế Là Hết' 0.3853333333333333 0.658 0.47100000000000003
#  0.027 47099.45 105.8 144 0.544 0.307 -10.531 0.026 0.814 0.329 149.877
#  292.0 'Vietnam']
# ['buitruonglinh' 'Dù Cho Mai Về Sau' 0.385 0.297 0.8 0.058 102464.188 40.0
#  65 0.632 0.579 -8.352 0.06 0.187 0.503 155.984 234.0 'Vietnam']
# ['hooligan.' 'To The Moon' 0.38352 0.338 0.76156 0.051 88925.344 47.688 74
#  0.648 0.543 -6.781 0.04 0.143 0.382 119.926 202.0 'Vietnam']
# ['Đức Phúc' 'Ngày Đầu Tiên' 0.3835 0.082 0.9484999999999999 0.12 209844.5
#  10.3 18 0.691 0.564 -4.606 0.027 0.774 0.356 110.043 209.0 'Vietnam']
# ['Jung Kook' 'Stay Alive (Prod. SUGA of BTS)' 0.3815 0.082
#  0.8915000000000001 0.171 300275.6 21.7 18 0.512 0.76 -5.889 0.068 0.299
#  0.495 130.096 211.0 'Vietnam']
# ['Charlie Puth' 'Cheating on You' 0.3765 0.288 0.7875 0.054 95074.786 42.5
#  63 0.749 0.535 -6.785 0.034 0.013 0.601 123.042 197.0 'Vietnam']
# ['Emcee L (Da LAB), Badbies'
#  'Sinh Ra Đã Là Thứ Đối Lập Nhau (feat. Badbies)' 0.37523 0.174 0.87969
#  0.072 127201.438 24.062 38 0.494 0.395 -8.653 0.03 0.887 0.179 141.464
#  234.0 'Vietnam']
# ['Hứa Kim Tuyền, Hoàng Duyên' 'Sài Gòn Đau Lòng Quá' 0.373445 0.114
#  0.903335 0.103 179952.75 19.333 25 0.418 0.382 -7.778 0.032 0.786 0.261
#  163.878 309.0 'Vietnam']
# ['Lewis Capaldi' 'Someone You Loved' 0.3729466666666667 0.648
#  0.44683999999999996 0.024 41537.842 110.632 142 0.501 0.405 -5.679 0.032
#  0.751 0.446 109.891 182.0 'Vietnam']
# ['V' 'Christmas Tree' 0.3725416666666667 0.114 0.895625 0.108 189239.062
#  20.875 25 0.437 0.384 -8.384 0.042 0.699 0.181 139.009 210.0 'Vietnam']
# ['Sơn Tùng M-TP' 'CÓ CHẮC YÊU LÀ ĐÂY' 0.3721566666666667 0.466
#  0.6084700000000001 0.042 73918.806 78.306 102 0.746 0.724 -3.976 0.05
#  0.119 0.596 95.003 202.0 'Vietnam']
# ['BTS' 'Not Today' 0.37166666666666665 0.009 0.955 0.151 264992.0 9.0 2
#  0.593 0.945 -3.408 0.126 0.002 0.674 110.023 232.0 'Vietnam']
# ['Thịnh Suy' 'tiny love' 0.3710366666666667 0.128 0.8911100000000001 0.094
#  164479.556 21.778 28 0.824 0.171 -15.871 0.053 0.857 0.693 100.036 158.0
#  'Vietnam']
# ['Bich Phuong, Phuc Du' 'từ chối nhẹ nhàng thôi' 0.3709366666666667 0.301
#  0.7628100000000001 0.049 85601.875 47.438 66 0.698 0.587 -4.318 0.057
#  0.717 0.569 88.006 247.0 'Vietnam']
# ['Truc Nhan' 'Có Không Giữ Mất Đừng Tìm' 0.3685833333333333 0.023 0.95875
#  0.124 217236.0 8.25 5 0.764 0.614 -6.586 0.038 0.603 0.502 132.004 216.0
#  'Vietnam']
# ['MIN' 'Trên Tình Bạn Dưới Tình Yêu' 0.3626766666666666 0.384
#  0.6590299999999999 0.045 78142.194 68.194 84 0.776 0.921 -3.032 0.038
#  0.189 0.598 108.961 199.0 'Vietnam']
# ['Hoang Thuy Linh' 'See Tình' 0.3624066666666666 0.078 0.9172199999999999
#  0.092 162221.333 16.556 17 0.846 0.755 -5.013 0.038 0.497 0.854 97.009
#  185.0 'Vietnam']
# ['Đen' 'Ai muốn nghe không' 0.361 0.005 0.955 0.123 216745.0 9.0 1 0.744
#  0.435 -14.157 0.098 0.851 0.445 87.984 308.0 'Vietnam']
# ['SOOBIN' 'Vai Lan Don Dua' 0.35633333333333334 0.826 0.225 0.018
#  31793.357 155.0 181 0.724 0.668 -4.035 0.058 0.555 0.427 135.046 171.0
#  'Vietnam']
# ['Juky San, REDT' 'Phải Chăng Em Đã Yêu? (feat. RedT)' 0.35289666666666664
#  0.142 0.8296899999999999 0.087 153448.438 34.062 31 0.69 0.615 -4.532
#  0.033 0.409 0.371 96.002 190.0 'Vietnam']

# %%
#create a connect and name the sqlite database for country attributes
country_attributes_conn = sqlite3.connect('country_attributes.sqlite')
print(countries_conn)
countries_attrib_df.to_sql('attributes' ,country_attributes_conn, if_exists='replace', index=False)
#check if the sqlite is working
countries_attrib_df = pd.read_sql_query("SELECT * FROM attributes",country_attributes_conn)
for attributes  in countries_attrib_df.values:
       print(attributes)
# Out:
# <sqlite3.Connection object at 0x000002C2B2D23E40>
# ['Argentina' 0.74 0.68 -5.22 0.13 0.23 0.65 120.36 206.66]
# ['Australia' 0.65 0.63 -6.48 0.1 0.25 0.5 120.49 210.16]
# ['Austria' 0.69 0.67 -6.32 0.11 0.21 0.53 123.42 187.42]
# ['Belarus' 0.69 0.66 -7.13 0.13 0.21 0.46 124.35 171.49]
# ['Belgium' 0.7 0.68 -6.2 0.11 0.22 0.55 122.5 197.81]
# ['Bolivia' 0.71 0.65 -5.49 0.1 0.27 0.6 125.12 203.42]
# ['Brazil' 0.68 0.71 -5.05 0.1 0.35 0.66 131.05 189.64]
# ['Bulgaria' 0.72 0.7 -5.95 0.13 0.15 0.56 129.03 200.56]
# ['Canada' 0.67 0.62 -6.6 0.11 0.24 0.49 120.19 202.06]
# ['Chile' 0.74 0.69 -5.33 0.12 0.24 0.62 120.36 215.59]
# ['China' 0.6 0.58 -7.08 0.06 0.4 0.46 124.8 228.04]
# ['Colombia' 0.73 0.68 -5.29 0.11 0.25 0.63 125.41 209.79]
# ['Costa Rica' 0.7 0.63 -5.56 0.1 0.29 0.59 127.66 205.12]
# ['Cyprus' 0.69 0.65 -6.72 0.13 0.25 0.5 121.08 196.22]
# ['Czech Republic' 0.67 0.67 -6.72 0.1 0.24 0.5 123.67 193.16]
# ['Denmark' 0.69 0.64 -6.38 0.11 0.23 0.55 119.43 188.07]
# ['Dominican Republic' 0.73 0.67 -5.45 0.13 0.28 0.58 125.1 203.2]
# ['Ecuador' 0.72 0.66 -5.68 0.11 0.28 0.59 123.57 203.84]
# ['Egypt' 0.71 0.63 -7.41 0.12 0.34 0.52 120.52 206.63]
# ['El Salvador' 0.72 0.65 -5.59 0.1 0.28 0.59 124.18 206.79]
# ['Estonia' 0.67 0.68 -6.44 0.1 0.19 0.5 120.48 196.09]
# ['Finland' 0.66 0.69 -6.37 0.08 0.17 0.53 122.34 200.29]
# ['France' 0.73 0.67 -6.52 0.14 0.28 0.56 123.78 197.83]
# ['Germany' 0.69 0.64 -6.72 0.13 0.23 0.5 123.02 186.5]
# ['Greece' 0.71 0.66 -7.11 0.17 0.27 0.5 123.46 197.12]
# ['Guatemala' 0.71 0.63 -5.66 0.09 0.31 0.62 124.82 203.82]
# ['Honduras' 0.7 0.64 -5.67 0.1 0.28 0.58 124.27 203.93]
# ['Hungary' 0.7 0.68 -6.18 0.1 0.21 0.53 120.81 192.21]
# ['Iceland' 0.65 0.55 -7.85 0.1 0.33 0.47 120.01 207.09]
# ['Thailand' 0.64 0.61 -6.63 0.07 0.34 0.54 120.98 217.64]
# ['Turkey' 0.65 0.61 -7.97 0.09 0.3 0.48 122.24 200.72]
# ['Ukraine' 0.7 0.65 -6.9 0.13 0.22 0.48 122.68 174.17]
# ['United Arab Emirates' 0.66 0.61 -6.55 0.1 0.28 0.49 119.04 200.76]
# ['United Kingdom' 0.65 0.66 -6.44 0.11 0.24 0.53 122.01 205.71]
# ['United States of America' 0.66 0.62 -6.72 0.12 0.24 0.47 122.54 202.66]
# ['Uruguay' 0.72 0.68 -5.32 0.11 0.24 0.64 122.4 202.35]
# ['Venezuela' 0.72 0.69 -5.32 0.11 0.25 0.59 121.7 208.17]
# ['Vietnam' 0.64 0.53 -7.46 0.07 0.45 0.45 119.13 221.94]

# %%
#create a connect and name the sqlite database for fifty top genre
fifty_genre_conn = sqlite3.connect('fiftygenre_db.sqlite')
print(fifty_genre_conn)
top_fifty_genres_df.to_sql('genre', fifty_genre_conn, if_exists='replace', index=False)
#check if the sqlite is working
top_fifty_genres_df = pd.read_sql_query("SELECT * FROM genre", fifty_genre_conn)
for genre  in top_fifty_genres_df.values:
       print(genre)
# Out:
# <sqlite3.Connection object at 0x000002C2B2D19A80>
# ['pop' 107610]
# ['trap latino' 40392]
# ['latin' 34474]
# ['reggaeton' 33662]
# ['dance pop' 31377]
# ['rap' 19871]
# ['uk pop' 17790]
# ['k-pop' 15272]
# ['canadian pop' 14007]
# ['hip hop' 9630]
# ['reggaeton colombiano' 8903]
# ['pop rap' 8743]
# ['german hip hop' 8521]
# ['trap' 8477]
# ['latin pop' 8472]
# ['pop dance' 7472]
# ['melodic rap' 7364]
# ['tropical house' 6754]
# ['chicago rap' 6380]
# ['k-pop boy group' 6323]
# ['canadian contemporary r&b' 6282]
# ['latin hip hop' 6246]
# ['j-pop' 6231]
# ['australian hip hop' 6224]
# ['israeli pop' 6030]
# ['trap argentino' 5795]
# ['edm' 5748]
# ['reggaeton flow' 5743]
# ['r&b' 5698]
# ['puerto rican pop' 5697]
# ['cantopop' 5617]
# ['modern rock' 5536]
# ['danish pop' 5384]
# ['mandopop' 5326]
# ['greek trap' 5243]
# ['indonesian pop' 5126]
# ['arrocha' 5052]
# ['brooklyn drill' 4974]
# ['electropop' 4889]
# ['italian pop' 4853]
# ['russian hip hop' 4566]
# ['rock' 4513]
# ['thai pop' 4431]
# ['slap house' 4414]
# ['dutch pop' 4376]
# ['post-teen pop' 4375]
# ['polish hip hop' 4142]
# ['egyptian hip hop' 4046]
# ['lgbtq+ hip hop' 4038]
# ['colombian pop' 4001]

# %%
top_fifty_genres_df.columns
# Out:
# Index(['ARTIST_GENRE', 'ARTIST_NAMES'], dtype='object')

# %%
#importing time to put a wait time between arguments
import time

# %%
#create a connect and name the sqlite database for coolness db
coolness_conn = sqlite3.connect('coolness_db.sqlite')
print(coolness_conn)
coolness_df.to_sql('coolness',coolness_conn, if_exists='replace', index=False)
#check if the sqlite is working
coolness_df = pd.read_sql_query("SELECT * FROM coolness", coolness_conn)
for coolness  in coolness_df:
       print(coolness)

time.sleep(5)
# Out:
# <sqlite3.Connection object at 0x000002C2B2D19990>
# ARTIST_NAMES
# TRACK_NAME
# WEEKS_ON_CHART
# RANK
# STREAMS
# WOC_RATIO
# RANK_PTS
# STREAMS_RATIO
# POPULARITY_SCORE

# %%
#create a single database
df1 = coolness_df
df2 = top_fifty_genres_df
df3 = all_countries_top_fifty_df
df4 = countries_attrib_df

my_dfs = {
    "coolness": df1,
    "fiftygenre": df2,
    "country" : df3, 
    "country_attributes": df4
}
with sqlite3.connect("songs_complete_db.sqlite") as songs_complete_db:
    for table_name, df in my_dfs.items():
        df.to_sql(table_name, songs_complete_db, if_exists="replace")

time.sleep(5)

# %%
#add primary key to country_attributes (1)

#connect to the database
conn = sqlite3.connect('songs_complete_db.sqlite')
c = conn.cursor()

c.executescript('''
    PRAGMA foreign_keys=off;

    BEGIN TRANSACTION;
    ALTER TABLE country_attributes RENAME TO old_table;

    /*create a new table with the same column names and types while
    defining a primary key for the desired column*/
    CREATE TABLE country_attributes (
      country TEXT PRIMARY KEY NOT NULL,
      danceability REAL,
      energy REAL,
      loudness REAL,
      speechiness REAL,
      acousticness REAL,
      valence REAL,
      tempo REAL,
      duration REAL);

    INSERT INTO country_attributes SELECT country, danceability, energy, loudness, speechiness, acousticness, valence, tempo, duration FROM old_table;

    DROP TABLE old_table;
    COMMIT TRANSACTION;

    PRAGMA foreign_keys=on;''')

#close out the connection
c.close()
conn.close()

time.sleep(5)

# %%
#add primary key to coolness (2)

#connect to the database
conn = sqlite3.connect('songs_complete_db.sqlite')
c = conn.cursor()

c.executescript('''
    PRAGMA foreign_keys=off;

    BEGIN TRANSACTION;
    ALTER TABLE coolness RENAME TO old_table;

    /*create a new table with the same column names and types while
    defining a primary key for the desired column*/
    CREATE TABLE coolness (
    artist_names TEXT,
    track_name TEXT,
    weeks_on_chart INTEGER,
    rank REAL,
    streams REAL,
    WOC_ratio REAL,
    rank_pts REAL,
    streams_ratio REAL,
    Popularity_Score REAL,
    PRIMARY KEY (artist_names, track_name)
    );

    INSERT INTO coolness SELECT artist_names, track_name, weeks_on_chart, rank, streams, WOC_ratio, rank_pts, streams_ratio, Popularity_Score FROM old_table;

    DROP TABLE old_table;
    COMMIT TRANSACTION;

    PRAGMA foreign_keys=on;''')

#close out the connection
c.close()
conn.close()

time.sleep(5)

# %%
#add primary key to fiftygenre (3)

#connect to the database
conn = sqlite3.connect('songs_complete_db.sqlite')
c = conn.cursor()

c.executescript('''
    PRAGMA foreign_keys=off;

    BEGIN TRANSACTION;
    ALTER TABLE fiftygenre RENAME TO old_table;

    /*create a new table with the same column names and types while
    defining a primary key for the desired column*/
    
    CREATE TABLE fiftygenre (
        artist_genre TEXT PRIMARY KEY NOT NULL,
        artist_names INTEGER
    );

    INSERT INTO fiftygenre SELECT artist_genre, ARTIST_NAMES FROM old_table;

    ALTER TABLE fiftygenre RENAME COLUMN ARTIST_NAMES TO ARTIST_COUNT;

    DROP TABLE old_table;

    COMMIT TRANSACTION;

    PRAGMA foreign_keys=on;''')

#close out the connection
c.close()
conn.close()

time.sleep(5)

# %%
#add primary key to country and rename to top_50_by_country (4)

#connect to the database
conn = sqlite3.connect('songs_complete_db.sqlite')
c = conn.cursor()

c.executescript('''
    PRAGMA foreign_keys=off;

    BEGIN TRANSACTION;
    ALTER TABLE country RENAME TO old_table;

    /*create a new table with the same column names and types while
    defining a primary key for the desired column*/
    DROP TABLE IF EXISTS top_50_by_country;
    CREATE TABLE top_50_by_country (
        artist_names TEXT,
        track_name TEXT,
        Popularity_Score REAL,
        WOC_ratio REAL,
        rank_pts REAL,
        streams_ratio REAL,
        streams REAL,
        rank REAL,
        weeks_on_chart INTEGER,
        danceability REAL,
        energy REAL,
        loudness REAL,
        speechiness REAL,
        acousticness REAL,
        valence REAL,
        tempo REAL,
        duration REAL,
        country TEXT,
        PRIMARY KEY (artist_names, track_name, country)
    );

    INSERT INTO top_50_by_country SELECT artist_names, track_name, Popularity_Score, WOC_ratio, rank_pts, streams_ratio, streams, rank, weeks_on_chart, danceability, energy, loudness, speechiness, acousticness, valence, tempo, duration, country FROM old_table;

    DROP TABLE old_table;
    COMMIT TRANSACTION;

    PRAGMA foreign_keys=on;''')

#close out the connection
c.close()
conn.close()

time.sleep(5)
