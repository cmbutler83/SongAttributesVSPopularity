# %%
import pandas as pd
csv_data = "dupl_removed_final3.csv"

# %%
music_df = pd.read_csv(csv_data)

# %%
music_df.head()
# Out:
#   artist_names          track_name  rank  weeks_on_chart  streams        week  \
# 0         SyKo  #BrooklynBloodPop!   189             2.0   6046.0  2021-07-29
# 1         SyKo  #BrooklynBloodPop!    79             1.0   7204.0  2021-05-06
# 2         SyKo  #BrooklynBloodPop!    54             2.0   9060.0  2021-05-13
# 3         SyKo  #BrooklynBloodPop!    71             3.0   8243.0  2021-05-20
# 4         SyKo  #BrooklynBloodPop!   108             4.0   7515.0  2021-05-27
#
#    danceability  energy  loudness  speechiness  acousticness  valence  \
# 0         0.691   0.814    -3.788        0.117        0.0164    0.509
# 1         0.691   0.814    -3.788        0.117        0.0164    0.509
# 2         0.691   0.814    -3.788        0.117        0.0164    0.509
# 3         0.691   0.814    -3.788        0.117        0.0164    0.509
# 4         0.691   0.814    -3.788        0.117        0.0164    0.509
#
#      tempo  duration   country
# 0  132.012     146.0  Bulgaria
# 1  132.012     146.0   Estonia
# 2  132.012     146.0   Estonia
# 3  132.012     146.0   Estonia
# 4  132.012     146.0   Estonia

# %%
countries_data = music_df.groupby(music_df['country'])['danceability', 'energy','loudness',
       'speechiness', 'acousticness','valence', 'tempo', 'duration'].mean()
# Out:
# C:\Users\cmbut\AppData\Local\Temp\ipykernel_255456\2272196859.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   countries_data = music_df.groupby(music_df['country'])['danceability', 'energy','loudness',

# %%
countries_attrib_df = pd.DataFrame(countries_data).sort_values(['country'])
countries_attrib_df = countries_attrib_df.reset_index()
countries_attrib_df
# Out:
#            country  danceability    energy  loudness  speechiness  \
# 0        Argentina      0.744013  0.675101 -5.216302     0.131787
# 1        Australia      0.647711  0.633686 -6.481121     0.095834
# 2          Austria      0.690939  0.671089 -6.318950     0.111944
# 3          Belarus      0.685134  0.656724 -7.133241     0.125515
# 4          Belgium      0.696079  0.677366 -6.198538     0.108677
# ..             ...           ...       ...       ...          ...
# 68  United Kingdom      0.653637  0.657538 -6.436920     0.111578
# 69   United States      0.664687  0.615787 -6.715155     0.118298
# 70         Uruguay      0.715186  0.675496 -5.322464     0.105967
# 71       Venezuela      0.724298  0.688508 -5.317021     0.110129
# 72         Vietnam      0.643859  0.533608 -7.457486     0.066739
#
#     acousticness   valence       tempo    duration
# 0       0.229910  0.646563  120.360768  206.661807
# 1       0.254743  0.504944  120.494618  210.157895
# 2       0.213600  0.532730  123.415775  187.416711
# 3       0.213192  0.455123  124.346252  171.488864
# 4       0.218400  0.549937  122.500907  197.808202
# ..           ...       ...         ...         ...
# 68      0.235264  0.526514  122.010783  205.712368
# 69      0.237849  0.471877  122.537318  202.663399
# 70      0.242609  0.636782  122.401861  202.354694
# 71      0.250157  0.587370  121.701712  208.170294
# 72      0.454610  0.446536  119.133977  221.938514
#
# [73 rows x 9 columns]

# %%
countries = []
countries = [column for column in countries_attrib_df['country']]
print(countries[0:73])
# Out:
# ['Argentina', 'Australia', 'Austria', 'Belarus', 'Belgium', 'Bolivia', 'Brazil', 'Bulgaria', 'Canada', 'Chile', 'Colombia', 'Costa Rica', 'Cyprus', 'Czech Republic', 'Denmark', 'Dominican Republic', 'Ecuador', 'Egypt', 'El Salvador', 'Estonia', 'Finland', 'France', 'Germany', 'Greece', 'Guatemala', 'Honduras', 'Hong Kong', 'Hungary', 'Iceland', 'India', 'Indonesia', 'Ireland', 'Israel', 'Italy', 'Japan', 'Kazakhstan', 'Korea', 'Latvia', 'Lithuania', 'Luxembourg', 'Malaysia', 'Mexico', 'Morocco', 'Netherlands', 'New Zealand', 'Nicaragua', 'Nigeria', 'Norway', 'Pakistan', 'Panama', 'Paraguay', 'Peru', 'Philippines', 'Poland', 'Portugal', 'Romania', 'Saudi Arabia', 'Singapore', 'Slovakia', 'South Africa', 'Spain', 'Sweden', 'Switzerland', 'Taiwan', 'Thailand', 'Turkey', 'Ukraine', 'United Arab Emirates', 'United Kingdom', 'United States', 'Uruguay', 'Venezuela', 'Vietnam']

# %%
csv_data2 = "artist_genres.csv"
genre_df = pd.read_csv(csv_data2)
genre_df
# Out:
#                                  artist_names            artist_genre
# 0                        Bad Bunny, Tony Dize           latin hip hop
# 1        Blessd, Justin Quiles, Lenny Tavárez               reggaeton
# 2        Blessd, Justin Quiles, Lenny Tavárez               reggaeton
# 3        Blessd, Justin Quiles, Lenny Tavárez          reggaeton flow
# 4                Eladio Carrion, Nicki Nicole             trap triste
# ...                                       ...                     ...
# 1099768                                   BTS         k-pop boy group
# 1099769                                   BTS         k-pop boy group
# 1099770                                 GAYLE  modern alternative pop
# 1099771                                Da LAB                   v-pop
# 1099772                                   Vũ.                   v-pop
#
# [1099773 rows x 2 columns]

# %%
genre_df = genre_df.loc[genre_df['artist_genre'] != '0']

# %%
most_pop_genres_df = pd.DataFrame(genre_df.groupby(genre_df['artist_genre']).count())

most_pop_genres_df = most_pop_genres_df.sort_values(['artist_names'], ascending=False)
top_fifty_genres_df = most_pop_genres_df.head(50)

top_fifty_genres_df
# Out:
#                            artist_names
# artist_genre
# pop                              107610
# trap latino                       40392
# latin                             34474
# reggaeton                         33662
# dance pop                         31377
# rap                               19871
# uk pop                            17790
# k-pop                             15272
# canadian pop                      14007
# hip hop                            9630
# reggaeton colombiano               8903
# pop rap                            8743
# german hip hop                     8521
# trap                               8477
# latin pop                          8472
# pop dance                          7472
# melodic rap                        7364
# tropical house                     6754
# chicago rap                        6380
# k-pop boy group                    6323
# canadian contemporary r&b          6282
# latin hip hop                      6246
# j-pop                              6231
# australian hip hop                 6224
# israeli pop                        6030
# trap argentino                     5795
# edm                                5748
# reggaeton flow                     5743
# r&b                                5698
# puerto rican pop                   5697
# cantopop                           5617
# modern rock                        5536
# danish pop                         5384
# mandopop                           5326
# greek trap                         5243
# indonesian pop                     5126
# arrocha                            5052
# brooklyn drill                     4974
# electropop                         4889
# italian pop                        4853
# russian hip hop                    4566
# rock                               4513
# thai pop                           4431
# slap house                         4414
# dutch pop                          4376
# post-teen pop                      4375
# polish hip hop                     4142
# egyptian hip hop                   4046
# lgbtq+ hip hop                     4038
# colombian pop                      4001

# %%
top_fifty_genres_df.columns
# Out:
# Index(['artist_names'], dtype='object')

# %%
music_df.columns
# Out:
# Index(['artist_names', 'track_name', 'rank', 'weeks_on_chart', 'streams',
#        'week', 'danceability', 'energy', 'loudness', 'speechiness',
#        'acousticness', 'valence', 'tempo', 'duration', 'country'],
#       dtype='object')

# %%
aver_rank_streams = music_df.groupby(['artist_names','track_name'])['rank','streams'].mean().round(0)
aver_rank_streams_df = pd.DataFrame(aver_rank_streams)
#music_df.groupby(music_df['country'])['danceability', 'energy','loudness',
       #'speechiness', 'acousticness','valence', 'tempo', 'duration'].mean()
aver_rank_streams_df
# Out:
# C:\Users\cmbut\AppData\Local\Temp\ipykernel_255456\3659512825.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   aver_rank_streams = music_df.groupby(['artist_names','track_name'])['rank','streams'].mean().round(0)
#                                                                                rank  \
# artist_names                      track_name
# #TocoParaVos, El Reja, Marka Akme Se Picó                                      94.0
# $NOT                              GOSHA                                       155.0
# $NOT, A$AP Rocky                  Doja                                        108.0
# $NOT, Lil Skies, Internet Money   Whipski (feat. Lil Skies & Internet Money)  138.0
# $OHO BANI                         VIRAL                                       138.0
# ...                                                                             ...
# 魚丁糸                               Leave Me Alone (魚in summer)                 198.0
#                                   Sorry青春                                     119.0
#                                   終點起點                                         81.0
# 麗英@小薯茄                            東京一轉                                        146.0
# 黄霄雲                               STARS AND SEA                               110.0
#
#                                                                                streams
# artist_names                      track_name
# #TocoParaVos, El Reja, Marka Akme Se Picó                                     137573.0
# $NOT                              GOSHA                                         5724.0
# $NOT, A$AP Rocky                  Doja                                        242309.0
# $NOT, Lil Skies, Internet Money   Whipski (feat. Lil Skies & Internet Money)  440500.0
# $OHO BANI                         VIRAL                                       398532.0
# ...                                                                                ...
# 魚丁糸                               Leave Me Alone (魚in summer)                  44632.0
#                                   Sorry青春                                      56957.0
#                                   終點起點                                         77530.0
# 麗英@小薯茄                            東京一轉                                         28442.0
# 黄霄雲                               STARS AND SEA                                70289.0
#
# [27905 rows x 2 columns]

# %%
#aver_rank_streams_df = aver_rank_streams_df.reset_index()
aver_rank_streams_df = aver_rank_streams_df[['artist_names','track_name','rank','streams']]
aver_rank_streams_df
# Out:
#                             artist_names  \
# 0      #TocoParaVos, El Reja, Marka Akme
# 1                                   $NOT
# 2                       $NOT, A$AP Rocky
# 3        $NOT, Lil Skies, Internet Money
# 4                              $OHO BANI
# ...                                  ...
# 27900                                魚丁糸
# 27901                                魚丁糸
# 27902                                魚丁糸
# 27903                             麗英@小薯茄
# 27904                                黄霄雲
#
#                                        track_name   rank   streams
# 0                                         Se Picó   94.0  137573.0
# 1                                           GOSHA  155.0    5724.0
# 2                                            Doja  108.0  242309.0
# 3      Whipski (feat. Lil Skies & Internet Money)  138.0  440500.0
# 4                                           VIRAL  138.0  398532.0
# ...                                           ...    ...       ...
# 27900                 Leave Me Alone (魚in summer)  198.0   44632.0
# 27901                                     Sorry青春  119.0   56957.0
# 27902                                        終點起點   81.0   77530.0
# 27903                                        東京一轉  146.0   28442.0
# 27904                               STARS AND SEA  110.0   70289.0
#
# [27905 rows x 4 columns]

# %%
max_weeks_on_chart = music_df.groupby(['artist_names','track_name'])['weeks_on_chart'].max()
max_weeks_on_chart_df = pd.DataFrame(max_weeks_on_chart).sort_values(['weeks_on_chart'], ascending=False)
max_weeks_on_chart_df = max_weeks_on_chart_df.reset_index()

# %%
max_weeks_on_chart_df.columns
# Out:
# Index(['artist_names', 'track_name', 'weeks_on_chart'], dtype='object')

# %%
coolness_df = pd.merge(max_weeks_on_chart_df,aver_rank_streams_df,how='left',left_on=['artist_names','track_name'],right_on=['artist_names','track_name'])

# %%
coolness_df['WOC_ratio'] = coolness_df['weeks_on_chart'].div(290).round(3)
coolness_df.head(40)
# Out:
#                                          artist_names  \
# 0                                          Ed Sheeran
# 1                                           Hebe Tien
# 2   Anuel AA, Daddy Yankee, Zion & Lennox, Farruko...
# 3                                        James Arthur
# 4                                        South Border
# 5                                           Eric Chou
# 6                                           Dear Jane
# 7                                         The Killers
# 8                                         Danny Ocean
# 9                                          Jason Chan
# 10                                Alejandro Fernández
# 11                                           Jay Chou
# 12                                      León Larregui
# 13                                            Kay Tse
# 14                                            Bacilos
# 15                                     Terence Siufay
# 16                                        Luis Miguel
# 17                                       Payung Teduh
# 18                           The Chainsmokers, Halsey
# 19                                             G.E.M.
# 20                      Bonez MC, RAF Camora, Maxwell
# 21                                          Vance Joy
# 22                                     Punnany Massif
# 23                                           Jay Chou
# 24                                              Oasis
# 25                                    Imagine Dragons
# 26                                    Christina Perri
# 27                          Yura Yunita, Glenn Fredly
# 28                                       mor ve ötesi
# 29                         The Chainsmokers, Coldplay
# 30                                             Eagles
# 31                                     Bubbi Morthens
# 32                                         Ed Sheeran
# 33                                     Manuel Medrano
# 34                                     Up Dharma Down
# 35                                        Eraserheads
# 36                                         Ed Sheeran
# 37                                            Hjálmar
# 38                                            J. Cole
# 39                                        Hins Cheung
#
#                                            track_name  weeks_on_chart   rank  \
# 0                                          Photograph           290.0  147.0
# 1                                                 小幸運           290.0  108.0
# 2                                        Sola (Remix)           290.0  137.0
# 3                                Say You Won't Let Go           290.0  124.0
# 4                                             Rainbow           290.0   78.0
# 5   How Have You Been? - Ending Theme Song of TVBS...           290.0  100.0
# 6                                          You and Me           290.0  118.0
# 7                                      Mr. Brightside           290.0   97.0
# 8                                           Me Rehúso           290.0   97.0
# 9                                                你瞞我瞞           290.0  111.0
# 10                              Me Dediqué a Perderte           290.0  159.0
# 11                                               告白氣球           290.0  118.0
# 12                                            Brillas           290.0  100.0
# 13                                                囍帖街           290.0   94.0
# 14                                           Caraluna           290.0  149.0
# 15                                       Shi Guang Ji           290.0  143.0
# 16                            Ahora Te Puedes Marchar           290.0  141.0
# 17             Untuk Perempuan Yang Sedang Di Pelukan           290.0  112.0
# 18                                             Closer           289.0  150.0
# 19                      光年之外 (電影 《Passengers》 中國區主題曲)           289.0  137.0
# 20                                     Ohne mein Team           288.0  108.0
# 21                                            Riptide           286.0  139.0
# 22                                             Élvezd           285.0  108.0
# 23                                                 晴天           285.0  145.0
# 24                            Wonderwall - Remastered           285.0  135.0
# 25                                           Believer           284.0  157.0
# 26                                   A Thousand Years           284.0  169.0
# 27                                  Cinta Dan Rahasia           283.0  146.0
# 28                                     Bir Derdim Var           283.0  101.0
# 29                           Something Just Like This           282.0  149.0
# 30                   Hotel California - 2013 Remaster           282.0  137.0
# 31                                     Rómeó og Júlía           281.0   61.0
# 32                                            Perfect           280.0  142.0
# 33                                       Bajo El Agua           280.0  165.0
# 34                                            Tadhana           278.0  139.0
# 35                                Ang Huling El Bimbo           278.0  150.0
# 36                                       Shape of You           277.0  157.0
# 37                                 Leiðin okkar allra           277.0  115.0
# 38                                     No Role Modelz           277.0  114.0
# 39                                                 春秋           276.0   66.0
#
#      streams  WOC_ratio  rank_pts  streams_ratio
# 0   130715.0      1.000     0.265          0.032
# 1    54015.0      1.000     0.460          0.013
# 2    45522.0      1.000     0.315          0.011
# 3   163759.0      1.000     0.380          0.041
# 4   386851.0      1.000     0.610          0.096
# 5    58119.0      1.000     0.500          0.014
# 6    32287.0      1.000     0.410          0.008
# 7   591710.0      1.000     0.515          0.147
# 8   177402.0      1.000     0.515          0.044
# 9    33423.0      1.000     0.445          0.008
# 10  146012.0      1.000     0.205          0.036
# 11   48360.0      1.000     0.410          0.012
# 12  979170.0      1.000     0.500          0.243
# 13   36024.0      1.000     0.530          0.009
# 14   51525.0      1.000     0.255          0.013
# 15   26863.0      1.000     0.285          0.007
# 16  364695.0      1.000     0.295          0.091
# 17  350486.0      1.000     0.440          0.087
# 18  116525.0      0.997     0.250          0.029
# 19   54516.0      0.997     0.315          0.014
# 20   66826.0      0.993     0.460          0.017
# 21  132946.0      0.986     0.305          0.033
# 22   30988.0      0.983     0.460          0.008
# 23   45364.0      0.983     0.275          0.011
# 24  238526.0      0.983     0.325          0.059
# 25   82716.0      0.979     0.215          0.021
# 26   75528.0      0.979     0.155          0.019
# 27  298473.0      0.976     0.270          0.074
# 28  354796.0      0.976     0.495          0.088
# 29   41056.0      0.972     0.255          0.010
# 30  131745.0      0.972     0.315          0.033
# 31   10140.0      0.969     0.695          0.003
# 32   89770.0      0.966     0.290          0.022
# 33   59731.0      0.966     0.175          0.015
# 34  251876.0      0.959     0.305          0.063
# 35  246963.0      0.959     0.250          0.061
# 36   97713.0      0.955     0.215          0.024
# 37    6520.0      0.955     0.425          0.002
# 38  305076.0      0.955     0.430          0.076
# 39   47294.0      0.952     0.670          0.012

# %%
coolness_df['rank'].max()
# Out:
# 200.0

# %%
rank_pts = []
for row in coolness_df['rank']:
    rank_pts.append((100 - (row * .5))/100)

# %%
coolness_df['rank_pts'] = rank_pts

# %%
coolness_df.sort_values(['rank_pts'],ascending=False)
# Out:
#                                     artist_names  \
# 10104                                       Mata
# 20985                                  Formalite
# 11965                      Abdul Hannan, Rovalio
# 16122                             Light, Trannos
# 11575                                   Keung To
# ...                                          ...
# 21685                                 Oxxxymiron
# 24705  Falz, Kamo Mphela, Mpura, Niniola, Sayfar
# 21746                                    Bet Bet
# 24605                             Ege Zulu, Jore
# 14143                     Hard GZ, Nikone, Dualy
#
#                                       track_name  weeks_on_chart   rank  \
# 10104                     Kiss cam (podryw roku)            15.0    1.0
# 20985                                  Mahvettim             2.0    1.0
# 11965                                     Bikhra            10.0    1.0
# 16122                                      24hrs             5.0    1.0
# 11575                                      作品的說話            11.0    1.0
# ...                                          ...             ...    ...
# 21685                                       Улет             2.0  200.0
# 24705  Squander (feat. Niniola & Sayfar) - Remix             1.0  200.0
# 21746                          Man Vienalga Viss             2.0  200.0
# 24605                                  Peter Pan             1.0  200.0
# 14143                                    Lo Real             7.0  200.0
#
#          streams  WOC_ratio  rank_pts  streams_ratio
# 10104  2026317.0      0.052     0.995          0.503
# 20985    23120.0      0.007     0.995          0.006
# 11965   203875.0      0.034     0.995          0.051
# 16122   503930.0      0.017     0.995          0.125
# 11575   285090.0      0.038     0.995          0.071
# ...          ...        ...       ...            ...
# 21685    28298.0      0.007     0.000          0.007
# 24705    18243.0      0.003     0.000          0.005
# 21746     6123.0      0.007     0.000          0.002
# 24605    37287.0      0.003     0.000          0.009
# 14143   242176.0      0.024     0.000          0.060
#
# [27905 rows x 8 columns]

# %%
coolness_df['streams_ratio'] = coolness_df['streams'].div(4026918).round(3)
coolness_df.sort_values(['streams_ratio'],ascending=False)
# Out:
#              artist_names                 track_name  weeks_on_chart   rank  \
# 12446          João Gomes                      Dengo            10.0   20.0
# 8861                Tulus         Hati-Hati di Jalan            19.0    9.0
# 13722     Keisya Levronka             Tak Ingin Usai             8.0    3.0
# 4292   Henrique & Juliano  A Maior Saudade - Ao Vivo            45.0   19.0
# 12481      Jorge & Mateus         Todo Seu - Ao Vivo            10.0   18.0
# ...                   ...                        ...             ...    ...
# 22425     margiiela, Leis        üks öö (feat. Leis)             1.0  192.0
# 4053       Bubbi Morthens          Regnbogans stræti            48.0  150.0
# 22405         marp$, Raul                      reede             1.0  147.0
# 22381            yung fin                  Paparazzi             1.0  155.0
# 7202          Jón Jónsson          Ljúft að vera til            25.0  180.0
#
#          streams  WOC_ratio  rank_pts  streams_ratio
# 12446  4025622.0      0.034     0.900          1.000
# 8861   4026918.0      0.066     0.955          1.000
# 13722  3624225.0      0.028     0.985          0.900
# 4292   3549891.0      0.155     0.905          0.882
# 12481  3496942.0      0.034     0.910          0.868
# ...          ...        ...       ...            ...
# 22425     4584.0      0.003     0.040          0.001
# 4053      5626.0      0.166     0.250          0.001
# 22405     5387.0      0.003     0.265          0.001
# 22381     3938.0      0.003     0.225          0.001
# 7202      5726.0      0.086     0.100          0.001
#
# [27905 rows x 8 columns]

# %%
coolness_df['Popularity_Score'] = (coolness_df['WOC_ratio'] + coolness_df['rank_pts'] + coolness_df['streams_ratio'])/3

# %%
coolness_df = coolness_df.sort_values(['Popularity_Score'],ascending=False)
coolness_df.head(5)
# Out:
#              artist_names                 track_name  weeks_on_chart  rank  \
# 8861                Tulus         Hati-Hati di Jalan            19.0   9.0
# 4292   Henrique & Juliano  A Maior Saudade - Ao Vivo            45.0  19.0
# 12446          João Gomes                      Dengo            10.0  20.0
# 13722     Keisya Levronka             Tak Ingin Usai             8.0   3.0
# 12481      Jorge & Mateus         Todo Seu - Ao Vivo            10.0  18.0
#
#          streams  WOC_ratio  rank_pts  streams_ratio  Popularity_Score
# 8861   4026918.0      0.066     0.955          1.000          0.673667
# 4292   3549891.0      0.155     0.905          0.882          0.647333
# 12446  4025622.0      0.034     0.900          1.000          0.644667
# 13722  3624225.0      0.028     0.985          0.900          0.637667
# 12481  3496942.0      0.034     0.910          0.868          0.604000

# %%
usa_df = music_df.loc[music_df['country'] == 'United States']
usa_df.head(5)
# Out:
#      artist_names      track_name  rank  weeks_on_chart    streams  \
# 184  Cody Johnson  'Til You Can't   154             1.0  1556168.0
# 185  Cody Johnson  'Til You Can't   158             2.0  1689695.0
# 186  Cody Johnson  'Til You Can't   151             3.0  1727287.0
# 187  Cody Johnson  'Til You Can't   183             4.0  1576313.0
# 188  Cody Johnson  'Til You Can't   135             5.0  1793033.0
#
#            week  danceability  energy  loudness  speechiness  acousticness  \
# 184  2021-10-14         0.501   0.815    -4.865       0.0436        0.0513
# 185  2022-03-03         0.501   0.815    -4.865       0.0436        0.0513
# 186  2022-03-10         0.501   0.815    -4.865       0.0436        0.0513
# 187  2022-03-17         0.501   0.815    -4.865       0.0436        0.0513
# 188  2022-03-24         0.501   0.815    -4.865       0.0436        0.0513
#
#      valence    tempo  duration        country
# 184     0.46  160.087     224.0  United States
# 185     0.46  160.087     224.0  United States
# 186     0.46  160.087     224.0  United States
# 187     0.46  160.087     224.0  United States
# 188     0.46  160.087     224.0  United States

# %%
usa_df = usa_df.drop_duplicates(subset=['artist_names','track_name'],keep='first')
usa_df = usa_df[['artist_names','track_name','country']]
usa_df
# Out:
#               artist_names                                         track_name  \
# 184           Cody Johnson                                     'Til You Can't
# 778      Eminem, Nate Dogg                                   'Till I Collapse
# 799              Kay Starr  (Everybody's Waitin' For) The Man With The Bag...
# 824             Perry Como  (There's No Place Like) Home for the Holidays ...
# 1185           $uicideboy$  ...And to Those I Love, Thanks for Sticking Ar...
# ...                    ...                                                ...
# 687675        Taylor Swift                                             willow
# 687756  Tate McRae, Khalid                                            working
# 687758       Ariana Grande                                     worst behavior
# 687794        Gunna, Chlöe                                           you & me
# 689072          Tate McRae                                 you broke me first
#
#               country
# 184     United States
# 778     United States
# 799     United States
# 824     United States
# 1185    United States
# ...               ...
# 687675  United States
# 687756  United States
# 687758  United States
# 687794  United States
# 689072  United States
#
# [1645 rows x 3 columns]

# %%
usa_coolness_df = pd.merge(coolness_df,usa_df,how='inner',left_on=['artist_names','track_name'],right_on=['artist_names','track_name'])
usa_coolness_df = usa_coolness_df.sort_values(['Popularity_Score'],ascending=False)
usa_coolness_df.head(20)
# Out:
#                                 artist_names  \
# 0                                The Killers
# 1                                   Kid Cudi
# 2                              Fleetwood Mac
# 3                                    J. Cole
# 4                              Morgan Wallen
# 5                               James Arthur
# 6                Bad Bunny, Chencho Corleone
# 7                  Bad Bunny, Rauw Alejandro
# 8                               Lil Uzi Vert
# 9                     Bad Bunny, Jhay Cortez
# 10                              Travis Scott
# 11                                 Vance Joy
# 12                                    Eagles
# 13                                 Bad Bunny
# 14                  Bad Bunny, Bomba Estéreo
# 15      Trippie Redd, Ski Mask The Slump God
# 16                              Trippie Redd
# 17  Bobby "Boris" Pickett, The Crypt-Kickers
# 18                       J Balvin, Bad Bunny
# 19                                      Joji
#
#                                    track_name  weeks_on_chart   rank  \
# 0                              Mr. Brightside           290.0   97.0
# 1                                       love.             1.0   29.0
# 2                      Dreams - 2004 Remaster           260.0   96.0
# 3                              No Role Modelz           277.0  114.0
# 4                                   You Proof             9.0   40.0
# 5                        Say You Won't Let Go           290.0  124.0
# 6                             Me Porto Bonito            10.0   36.0
# 7                                       Party            10.0   18.0
# 8                               XO Tour Llif3           266.0  158.0
# 9                                       Tarot            10.0   18.0
# 10                                 goosebumps           274.0  133.0
# 11                                    Riptide           286.0  139.0
# 12           Hotel California - 2013 Remaster           282.0  137.0
# 13                           Tití Me Preguntó            10.0   19.0
# 14                              Ojitos Lindos            10.0   34.0
# 15  Demon Time (feat. Ski Mask The Slump God)             1.0   63.0
# 16                                 Super Cell             1.0   65.0
# 17                               Monster Mash             5.0   31.0
# 18                                 LA CANCIÓN           159.0   71.0
# 19                   SLOW DANCING IN THE DARK           198.0  133.0
#
#       streams  WOC_ratio  rank_pts  streams_ratio  Popularity_Score  \
# 0    591710.0      1.000     0.515          0.147          0.554000
# 1   3233804.0      0.003     0.855          0.803          0.553667
# 2    481432.0      0.897     0.520          0.120          0.512333
# 3    305076.0      0.955     0.430          0.076          0.487000
# 4   2442435.0      0.031     0.800          0.607          0.479333
# 5    163759.0      1.000     0.380          0.041          0.473667
# 6   2216389.0      0.034     0.820          0.550          0.468000
# 7   1839393.0      0.034     0.910          0.457          0.467000
# 8    946951.0      0.917     0.210          0.235          0.454000
# 9   1574209.0      0.034     0.910          0.391          0.445000
# 10   208581.0      0.945     0.335          0.052          0.444000
# 11   132946.0      0.986     0.305          0.033          0.441333
# 12   131745.0      0.972     0.315          0.033          0.440000
# 13  1525165.0      0.034     0.905          0.379          0.439333
# 14  1805233.0      0.034     0.830          0.448          0.437333
# 15  2503491.0      0.003     0.685          0.622          0.436667
# 16  2485063.0      0.003     0.675          0.617          0.431667
# 17  1740585.0      0.017     0.845          0.432          0.431333
# 18   396512.0      0.548     0.645          0.098          0.430333
# 19  1057741.0      0.683     0.335          0.263          0.427000
#
#           country
# 0   United States
# 1   United States
# 2   United States
# 3   United States
# 4   United States
# 5   United States
# 6   United States
# 7   United States
# 8   United States
# 9   United States
# 10  United States
# 11  United States
# 12  United States
# 13  United States
# 14  United States
# 15  United States
# 16  United States
# 17  United States
# 18  United States
# 19  United States

# %%
x = usa_coolness_df['weeks_on_chart'].max() 

usa_coolness_df['weeks_on_chart'].div(x)
#argentina_song_grpd['WOC_ratio'] = argentina_song_grpd['weeks_on_chart'].div(147).round(3)

# %%
# applying groupby() function to
# group the data on team value.
gk = music_df.groupby('country')
  
# Let's print the first entries
# in all the groups formed.
#gk.first()
argentina_df = gk.get_group('Argentina')
argentina_df

argentina_song_grpd = argentina_df.groupby(['artist_names','track_name']).aggregate({'streams':'mean','rank':'mean','weeks_on_chart':'max','danceability':'mean', 'energy':'mean','loudness':'mean',
       'speechiness':'mean', 'acousticness':'mean','valence':'mean', 'tempo':'mean', 'duration':'mean'}).round(3)

       #grouped = df.groupby(['Region', 'Type']).aggregate({'Units': 'mean', 'Sales': ['min', 'max']})
argentina_song_grpd.sort_values(['weeks_on_chart'],ascending=False)
argentina_song_grpd = argentina_song_grpd.reset_index() 
argentina_song_grpd['WOC_ratio'] = argentina_song_grpd['weeks_on_chart'].div(147).round(3)
argentina_song_grpd.head(5)

argentina_song_grpd['rank'].max()
rank_pts = []
for row in argentina_song_grpd['rank']:
    rank_pts.append((100 - (row * .5))/100)

argentina_song_grpd['rank_pts'] = rank_pts
argentina_song_grpd.head(5)

argentina_song_grpd.sort_values(['streams'],ascending=False)

argentina_song_grpd['streams_ratio'] = argentina_song_grpd['streams'].div(3357665).round(3)
argentina_song_grpd.sort_values(['streams_ratio'],ascending=False)

argentina_song_grpd['Popularity_Score'] = (argentina_song_grpd['WOC_ratio'] + argentina_song_grpd['rank_pts'] + argentina_song_grpd['streams_ratio'])/3

argentina_song_grpd.columns
argentina_best_songs = argentina_song_grpd[['artist_names', 'track_name', 'Popularity_Score', 'WOC_ratio', 'rank_pts',
       'streams_ratio','streams', 'rank', 'weeks_on_chart',
       'danceability', 'energy', 'loudness', 'speechiness', 'acousticness',
       'valence', 'tempo', 'duration']]
argentina_best_songs = argentina_best_songs.sort_values(['Popularity_Score'],ascending=False)
argentina_top_fifty = argentina_best_songs.head(50)
argentina_top_fifty
# Out:
#                        artist_names                             track_name  \
# 144                 YSY A, Bizarrap  #Ysya2020 Vol. 6 - Un Flow de Infarto
# 2752                Anuel AA, Ozuna                                    100
# 5434    Rauw Alejandro, Mr. Naisgai                              2/Catorce
# 5435    Rauw Alejandro, Mr. Naisgai                              2/Catorce
# 5436    Rauw Alejandro, Mr. Naisgai                              2/Catorce
# ...                             ...                                    ...
# 691052         Trueno, Taiu, TATOOL                                   Ñeri
# 691053         Trueno, Taiu, TATOOL                                   Ñeri
# 691054         Trueno, Taiu, TATOOL                                   Ñeri
# 691055         Trueno, Taiu, TATOOL                                   Ñeri
# 691056         Trueno, Taiu, TATOOL                                   Ñeri
#
#         rank  weeks_on_chart   streams        week  danceability  energy  \
# 144      200             7.0  184451.0  2021-02-04         0.789   0.492
# 2752     152             1.0  220909.0  2021-02-11         0.769   0.455
# 5434     183             1.0  179831.0  2021-04-15         0.540   0.455
# 5435     106             3.0  285558.0  2021-04-29         0.540   0.455
# 5436      50             4.0  510877.0  2021-05-06         0.540   0.455
# ...      ...             ...       ...         ...           ...     ...
# 691052    97            22.0  298651.0  2021-02-11         0.573   0.794
# 691053   126            27.0  237265.0  2021-03-18         0.573   0.794
# 691054   141            28.0  220951.0  2021-03-25         0.573   0.794
# 691055   142            29.0  222040.0  2021-04-01         0.573   0.794
# 691056   191            31.0  177101.0  2021-04-15         0.573   0.794
#
#         loudness  speechiness  acousticness  valence    tempo  duration  \
# 144       -6.962        0.470         0.173    0.212   88.717     142.0
# 2752      -5.698        0.155         0.554    0.293   95.097     215.0
# 5434      -5.988        0.224         0.675    0.432   83.876     212.0
# 5435      -5.988        0.224         0.675    0.432   83.876     212.0
# 5436      -5.988        0.224         0.675    0.432   83.876     212.0
# ...          ...          ...           ...      ...      ...       ...
# 691052    -4.469        0.244         0.591    0.764  187.727     195.0
# 691053    -4.469        0.244         0.591    0.764  187.727     195.0
# 691054    -4.469        0.244         0.591    0.764  187.727     195.0
# 691055    -4.469        0.244         0.591    0.764  187.727     195.0
# 691056    -4.469        0.244         0.591    0.764  187.727     195.0
#
#           country
# 144     Argentina
# 2752    Argentina
# 5434    Argentina
# 5435    Argentina
# 5436    Argentina
# ...           ...
# 691052  Argentina
# 691053  Argentina
# 691054  Argentina
# 691055  Argentina
# 691056  Argentina
#
# [4870 rows x 15 columns]

# %%
#Argentina DataFrame
# applying groupby() function to
# group the data on team value.
gk = music_df.groupby('country')
  
# Let's print the first entries
# in all the groups formed.
#gk.first()
argentina_df = gk.get_group('Argentina')

argentina_song_grpd = argentina_df.groupby(['artist_names','track_name']).aggregate({'streams':'mean','rank':'mean','weeks_on_chart':'max','danceability':'mean', 'energy':'mean','loudness':'mean',
       'speechiness':'mean', 'acousticness':'mean','valence':'mean', 'tempo':'mean', 'duration':'mean'}).round(3)
argentina_song_grpd = argentina_song_grpd.reset_index() 
argentina_song_grpd['country'] = 'Argentina'
       
argentina_song_grpd.sort_values(['weeks_on_chart'],ascending=False)

x= argentina_song_grpd['weeks_on_chart'].max()
argentina_song_grpd['WOC_ratio'] = argentina_song_grpd['weeks_on_chart'].div(x).round(3)
argentina_song_grpd.head(5)

argentina_song_grpd['rank'].max()
rank_pts = []
for row in argentina_song_grpd['rank']:
    rank_pts.append((100 - (row * .5))/100)

argentina_song_grpd['rank_pts'] = rank_pts
argentina_song_grpd.head(5)

argentina_song_grpd.sort_values(['streams'],ascending=False)
y = argentina_song_grpd['streams'].max()
argentina_song_grpd['streams_ratio'] = argentina_song_grpd['streams'].div(y).round(3)
argentina_song_grpd.sort_values(['streams_ratio'],ascending=False)

argentina_song_grpd['Popularity_Score'] = (argentina_song_grpd['WOC_ratio'] + argentina_song_grpd['rank_pts'] + argentina_song_grpd['streams_ratio'])/3

argentina_song_grpd.columns
argentina_best_songs = argentina_song_grpd[['artist_names', 'track_name', 'Popularity_Score', 'WOC_ratio', 'rank_pts',
       'streams_ratio','streams', 'rank', 'weeks_on_chart',
       'danceability', 'energy', 'loudness', 'speechiness', 'acousticness',
       'valence', 'tempo', 'duration','country']]
argentina_best_songs = argentina_best_songs.sort_values(['Popularity_Score'],ascending=False)
argentina_top_fifty = argentina_best_songs.head(50)
argentina_top_fifty.head(5)
# Out:
#                     artist_names                             track_name  \
# 62             Bizarrap, Quevedo  Quevedo: Bzrp Music Sessions, Vol. 52
# 419          TINI, Maria Becerra                               Miénteme
# 31      Bad Bunny, Bomba Estéreo                          Ojitos Lindos
# 33   Bad Bunny, Chencho Corleone                        Me Porto Bonito
# 417                TINI, L-Gante                                    Bar
#
#      Popularity_Score  WOC_ratio  rank_pts  streams_ratio      streams  \
# 62           0.626333      0.014  0.865000          1.000  3357665.500
# 419          0.602362      0.429  0.892085          0.486  1631911.556
# 31           0.585112      0.068  0.983335          0.704  2365299.333
# 33           0.578778      0.068  0.978335          0.690  2315401.667
# 417          0.572930      0.238  0.905790          0.575  1929734.263
#
#        rank  weeks_on_chart  danceability  energy  loudness  speechiness  \
# 62   27.000             2.0         0.621   0.782    -5.548        0.044
# 419  21.583            63.0         0.850   0.541    -4.522        0.067
# 31    3.333            10.0         0.647   0.686    -5.745        0.041
# 33    4.333            10.0         0.911   0.712    -5.105        0.082
# 417  18.842            35.0         0.523   0.691    -3.802        0.083
#
#      acousticness  valence    tempo  duration    country
# 62          0.012    0.550  128.033     199.0  Argentina
# 419         0.161    0.916   92.003     165.0  Argentina
# 31          0.080    0.268   79.928     258.0  Argentina
# 33          0.090    0.425   92.005     179.0  Argentina
# 417         0.133    0.677   94.148     160.0  Argentina

# %%
y
# Out:
# 3357665.5

# %%
#Australia DataFrame
# applying groupby() function to
# group the data on team value.
gk = music_df.groupby('country')
  
# Let's print the first entries
# in all the groups formed.
#gk.first()
Australia_df = gk.get_group('Australia')

Australia_song_grpd = Australia_df.groupby(['artist_names','track_name']).aggregate({'streams':'mean','rank':'mean','weeks_on_chart':'max','danceability':'mean', 'energy':'mean','loudness':'mean',
       'speechiness':'mean', 'acousticness':'mean','valence':'mean', 'tempo':'mean', 'duration':'mean'}).round(3)
Australia_song_grpd = Australia_song_grpd.reset_index() 
Australia_song_grpd['country'] = 'Australia'
       
Australia_song_grpd.sort_values(['weeks_on_chart'],ascending=False)

x= Australia_song_grpd['weeks_on_chart'].max()
Australia_song_grpd['WOC_ratio'] = Australia_song_grpd['weeks_on_chart'].div(x).round(3)
Australia_song_grpd.head(5)

Australia_song_grpd['rank'].max()
rank_pts = []
for row in Australia_song_grpd['rank']:
    rank_pts.append((100 - (row * .5))/100)

Australia_song_grpd['rank_pts'] = rank_pts
Australia_song_grpd.head(5)

Australia_song_grpd.sort_values(['streams'],ascending=False)
y = Australia_song_grpd['streams'].max()
Australia_song_grpd['streams_ratio'] = Australia_song_grpd['streams'].div(y).round(3)
Australia_song_grpd.sort_values(['streams_ratio'],ascending=False)

Australia_song_grpd['Popularity_Score'] = (Australia_song_grpd['WOC_ratio'] + Australia_song_grpd['rank_pts'] + Australia_song_grpd['streams_ratio'])/3

Australia_song_grpd.columns
Australia_best_songs = Australia_song_grpd[['artist_names', 'track_name', 'Popularity_Score', 'WOC_ratio', 'rank_pts',
       'streams_ratio','streams', 'rank', 'weeks_on_chart',
       'danceability', 'energy', 'loudness', 'speechiness', 'acousticness',
       'valence', 'tempo', 'duration','country']]
Australia_best_songs = Australia_best_songs.sort_values(['Popularity_Score'],ascending=False)
Australia_top_fifty = Australia_best_songs.head(50)
Australia_top_fifty.head(5)
# Out:
#       artist_names                                         track_name  \
# 632    The Killers                                     Mr. Brightside
# 314           Joji                                      Glimpse of Us
# 238  Glass Animals                                         Heat Waves
# 251   Harry Styles                                          As It Was
# 352      Kate Bush  Running Up That Hill (A Deal With God) - 2018 ...
#
#      Popularity_Score  WOC_ratio  rank_pts  streams_ratio      streams  \
# 632          0.674722      1.000  0.794165          0.230   466052.042
# 314          0.668333      0.010  0.995000          1.000  2027796.000
# 238          0.647445      0.347  0.978335          0.617  1251455.833
# 251          0.646333      0.045  0.989000          0.905  1835773.800
# 352          0.638222      0.017  0.991665          0.906  1837280.333
#
#        rank  weeks_on_chart  danceability  energy  loudness  speechiness  \
# 632  41.167           288.0         0.352   0.911    -5.230        0.075
# 314   1.000             3.0         0.440   0.317    -9.258        0.053
# 238   4.333           100.0         0.761   0.525    -6.900        0.094
# 251   2.200            13.0         0.520   0.731    -5.338        0.056
# 352   1.667             5.0         0.629   0.547   -13.123        0.055
#
#      acousticness  valence    tempo  duration    country
# 632         0.001    0.236  148.033     223.0  Australia
# 314         0.891    0.268  169.914     233.0  Australia
# 238         0.440    0.531   80.870     239.0  Australia
# 251         0.342    0.662  173.930     167.0  Australia
# 352         0.720    0.197  108.375     299.0  Australia

# %%
#Austria DataFrame
# applying groupby() function to
# group the data on team value.
gk = music_df.groupby('country')
  
# Let's print the first entries
# in all the groups formed.
#gk.first()
Austria_df = gk.get_group('Austria')

Austria_song_grpd = Austria_df.groupby(['artist_names','track_name']).aggregate({'streams':'mean','rank':'mean','weeks_on_chart':'max','danceability':'mean', 'energy':'mean','loudness':'mean',
       'speechiness':'mean', 'acousticness':'mean','valence':'mean', 'tempo':'mean', 'duration':'mean'}).round(3)
Austria_song_grpd = Austria_song_grpd.reset_index() 
Austria_song_grpd['country'] = 'Austria'
       
Austria_song_grpd.sort_values(['weeks_on_chart'],ascending=False)

x= Austria_song_grpd['weeks_on_chart'].max()
Austria_song_grpd['WOC_ratio'] = Austria_song_grpd['weeks_on_chart'].div(x).round(3)
Austria_song_grpd.head(5)

Austria_song_grpd['rank'].max()
rank_pts = []
for row in Austria_song_grpd['rank']:
    rank_pts.append((100 - (row * .5))/100)

Austria_song_grpd['rank_pts'] = rank_pts
Austria_song_grpd.head(5)

Austria_song_grpd.sort_values(['streams'],ascending=False)
y = Austria_song_grpd['streams'].max()
Austria_song_grpd['streams_ratio'] = Austria_song_grpd['streams'].div(y).round(3)
Austria_song_grpd.sort_values(['streams_ratio'],ascending=False)

Austria_song_grpd['Popularity_Score'] = (Austria_song_grpd['WOC_ratio'] + Austria_song_grpd['rank_pts'] + Austria_song_grpd['streams_ratio'])/3

Austria_song_grpd.columns
Austria_best_songs = Austria_song_grpd[['artist_names', 'track_name', 'Popularity_Score', 'WOC_ratio', 'rank_pts',
       'streams_ratio','streams', 'rank', 'weeks_on_chart',
       'danceability', 'energy', 'loudness', 'speechiness', 'acousticness',
       'valence', 'tempo', 'duration','country']]
Austria_best_songs = Austria_best_songs.sort_values(['Popularity_Score'],ascending=False)
Austria_top_fifty = Austria_best_songs.head(50)
Austria_top_fifty.head(5)
# Out:
#                        artist_names                       track_name  \
# 996                         Luciano                   Beautiful Girl
# 1702                          Wham!                   Last Christmas
# 644                    Harry Styles                        As It Was
# 242   Bonez MC, RAF Camora, Maxwell                   Ohne mein Team
# 1063                   Mariah Carey  All I Want for Christmas Is You
#
#       Popularity_Score  WOC_ratio  rank_pts  streams_ratio     streams  \
# 996           0.677212      0.038  0.993635          1.000  348741.091
# 1702          0.596875      0.132  0.920625          0.738  257306.125
# 644           0.582445      0.052  0.986335          0.709  247422.400
# 242           0.564145      1.000  0.547435          0.145   50648.895
# 1063          0.558518      0.142  0.855555          0.678  236421.000
#
#         rank  weeks_on_chart  danceability  energy  loudness  speechiness  \
# 996    1.273            11.0         0.839   0.412    -8.816        0.094
# 1702  15.875            38.0         0.735   0.478   -12.472        0.029
# 644    2.733            15.0         0.520   0.731    -5.338        0.056
# 242   90.513           288.0         0.766   0.800    -6.062        0.094
# 1063  28.889            41.0         0.336   0.627    -7.463        0.038
#
#       acousticness  valence    tempo  duration  country
# 996          0.287    0.607  139.901     179.0  Austria
# 1702         0.189    0.947  107.682     263.0  Austria
# 644          0.342    0.662  173.930     167.0  Austria
# 242          0.160    0.635  129.999     189.0  Austria
# 1063         0.164    0.350  150.273     241.0  Austria

# %%
#Belarus Dataframe
# applying groupby() function to
# group the data on team value.
gk = music_df.groupby('country')
  
# Let's print the first entries
# in all the groups formed.
#gk.first()
Belarus_df = gk.get_group('Belarus')

Belarus_song_grpd = Belarus_df.groupby(['artist_names','track_name']).aggregate({'streams':'mean','rank':'mean','weeks_on_chart':'max','danceability':'mean', 'energy':'mean','loudness':'mean',
       'speechiness':'mean', 'acousticness':'mean','valence':'mean', 'tempo':'mean', 'duration':'mean'}).round(3)
Belarus_song_grpd = Belarus_song_grpd.reset_index() 
Belarus_song_grpd['country'] = 'Belarus'
       
Belarus_song_grpd.sort_values(['weeks_on_chart'],ascending=False)

x= Belarus_song_grpd['weeks_on_chart'].max()
Belarus_song_grpd['WOC_ratio'] = Belarus_song_grpd['weeks_on_chart'].div(x).round(3)
Belarus_song_grpd.head(5)

Belarus_song_grpd['rank'].max()
rank_pts = []
for row in Belarus_song_grpd['rank']:
    rank_pts.append((100 - (row * .5))/100)

Belarus_song_grpd['rank_pts'] = rank_pts
Belarus_song_grpd.head(5)

Belarus_song_grpd.sort_values(['streams'],ascending=False)
y = Belarus_song_grpd['streams'].max()
Belarus_song_grpd['streams_ratio'] = Belarus_song_grpd['streams'].div(y).round(3)
Belarus_song_grpd.sort_values(['streams_ratio'],ascending=False)

Belarus_song_grpd['Popularity_Score'] = (Belarus_song_grpd['WOC_ratio'] + Belarus_song_grpd['rank_pts'] + Belarus_song_grpd['streams_ratio'])/3

Belarus_song_grpd.columns
Belarus_best_songs = Belarus_song_grpd[['artist_names', 'track_name', 'Popularity_Score', 'WOC_ratio', 'rank_pts',
       'streams_ratio','streams', 'rank', 'weeks_on_chart',
       'danceability', 'energy', 'loudness', 'speechiness', 'acousticness',
       'valence', 'tempo', 'duration','country']]
Belarus_best_songs = Belarus_best_songs.sort_values(['Popularity_Score'],ascending=False)
Belarus_top_fifty = Belarus_best_songs.head(50)
Belarus_top_fifty.head(5)
# Out:
#       artist_names          track_name  Popularity_Score  WOC_ratio  rank_pts  \
# 394     shadowraze            showdown          0.864632      0.864  0.987895
# 391     shadowraze         astral step          0.835212      1.000  0.978635
# 465          Шайни               Yeyo!          0.773758      1.000  0.952275
# 346  WENARO, LXNER                 Лёд          0.773575      1.000  0.957725
# 360       fem.love  Фотографирую закат          0.759167      1.000  0.932500
#
#      streams_ratio    streams    rank  weeks_on_chart  danceability  energy  \
# 394          0.742  61562.105   2.421            19.0         0.714   0.630
# 391          0.527  43708.500   4.273            22.0         0.795   0.624
# 465          0.369  30624.773   9.545            22.0         0.716   0.800
# 346          0.363  30106.864   8.455            22.0         0.636   0.794
# 360          0.345  28608.545  13.500            22.0         0.413   0.902
#
#      loudness  speechiness  acousticness  valence    tempo  duration  country
# 394   -11.098        0.129         0.036    0.378  114.945     120.0  Belarus
# 391    -7.245        0.292         0.013    0.693   95.018     121.0  Belarus
# 465    -9.417        0.062         0.099    0.436  138.010     112.0  Belarus
# 346    -7.867        0.064         0.169    0.953  172.088     153.0  Belarus
# 360    -3.488        0.065         0.000    0.398  160.271     156.0  Belarus

# %%
#Belgium Dataframe
# applying groupby() function to
# group the data on team value.
gk = music_df.groupby('country')
  
# Let's print the first entries
# in all the groups formed.
#gk.first()
Belgium_df = gk.get_group('Belgium')

Belgium_song_grpd = Belgium_df.groupby(['artist_names','track_name']).aggregate({'streams':'mean','rank':'mean','weeks_on_chart':'max','danceability':'mean', 'energy':'mean','loudness':'mean',
       'speechiness':'mean', 'acousticness':'mean','valence':'mean', 'tempo':'mean', 'duration':'mean'}).round(3)
Belgium_song_grpd = Belgium_song_grpd.reset_index() 
Belgium_song_grpd['country'] = 'Belgium'
       
Belgium_song_grpd.sort_values(['weeks_on_chart'],ascending=False)

x= Belgium_song_grpd['weeks_on_chart'].max()
Belgium_song_grpd['WOC_ratio'] = Belgium_song_grpd['weeks_on_chart'].div(x).round(3)
Belgium_song_grpd.head(5)

Belgium_song_grpd['rank'].max()
rank_pts = []
for row in Belgium_song_grpd['rank']:
    rank_pts.append((100 - (row * .5))/100)

Belgium_song_grpd['rank_pts'] = rank_pts
Belgium_song_grpd.head(5)

Belgium_song_grpd.sort_values(['streams'],ascending=False)
y = Belgium_song_grpd['streams'].max()
Belgium_song_grpd['streams_ratio'] = Belgium_song_grpd['streams'].div(y).round(3)
Belgium_song_grpd.sort_values(['streams_ratio'],ascending=False)

Belgium_song_grpd['Popularity_Score'] = (Belgium_song_grpd['WOC_ratio'] + Belgium_song_grpd['rank_pts'] + Belgium_song_grpd['streams_ratio'])/3

Belgium_song_grpd.columns
Belgium_best_songs = Belgium_song_grpd[['artist_names', 'track_name', 'Popularity_Score', 'WOC_ratio', 'rank_pts',
       'streams_ratio','streams', 'rank', 'weeks_on_chart',
       'danceability', 'energy', 'loudness', 'speechiness', 'acousticness',
       'valence', 'tempo', 'duration','country']]
Belgium_best_songs = Belgium_best_songs.sort_values(['Popularity_Score'],ascending=False)
Belgium_top_fifty = Belgium_best_songs.head(50)
Belgium_top_fifty.head(5)
# Out:
#                      artist_names                 track_name  \
# 380                          MEAU         Dat heb jij gedaan
# 16                          Adele                 Easy On Me
# 214                 Glass Animals                 Heat Waves
# 201                         GAYLE                    abcdefu
# 576  The Kid LAROI, Justin Bieber  STAY (with Justin Bieber)
#
#      Popularity_Score  WOC_ratio  rank_pts  streams_ratio     streams    rank  \
# 380          0.679667      0.044  0.995000          1.000  406936.000   1.000
# 16           0.670555      0.072  0.956665          0.983  400033.333   8.667
# 214          0.669667      0.228  0.968000          0.813  331032.400   6.400
# 201          0.650000      0.056  0.990000          0.904  367894.000   2.000
# 576          0.650000      0.212  0.944000          0.794  322943.160  11.200
#
#      weeks_on_chart  danceability  energy  loudness  speechiness  \
# 380            11.0         0.690   0.274   -12.923        0.051
# 16             18.0         0.604   0.366    -7.519        0.028
# 214            57.0         0.761   0.525    -6.900        0.094
# 201            14.0         0.695   0.540    -5.692        0.049
# 576            53.0         0.591   0.764    -5.484        0.048
#
#      acousticness  valence    tempo  duration  country
# 380         0.845    0.663  131.704     211.0  Belgium
# 16          0.578    0.130  141.981     225.0  Belgium
# 214         0.440    0.531   80.870     239.0  Belgium
# 201         0.299    0.415  121.932     169.0  Belgium
# 576         0.038    0.478  169.928     142.0  Belgium

# %%
#Bolivia Dataframe
# applying groupby() function to
# group the data on team value.
gk = music_df.groupby('country')
  
# Let's print the first entries
# in all the groups formed.
#gk.first()
Bolivia_df = gk.get_group('Bolivia')

Bolivia_song_grpd = Bolivia_df.groupby(['artist_names','track_name']).aggregate({'streams':'mean','rank':'mean','weeks_on_chart':'max','danceability':'mean', 'energy':'mean','loudness':'mean',
       'speechiness':'mean', 'acousticness':'mean','valence':'mean', 'tempo':'mean', 'duration':'mean'}).round(3)
Bolivia_song_grpd = Bolivia_song_grpd.reset_index() 
Bolivia_song_grpd['country'] = 'Bolivia'
       
Bolivia_song_grpd.sort_values(['weeks_on_chart'],ascending=False)

x= Bolivia_song_grpd['weeks_on_chart'].max()
Bolivia_song_grpd['WOC_ratio'] = Bolivia_song_grpd['weeks_on_chart'].div(x).round(3)
Bolivia_song_grpd.head(5)

Bolivia_song_grpd['rank'].max()
rank_pts = []
for row in Bolivia_song_grpd['rank']:
    rank_pts.append((100 - (row * .5))/100)

Bolivia_song_grpd['rank_pts'] = rank_pts
Bolivia_song_grpd.head(5)

Bolivia_song_grpd.sort_values(['streams'],ascending=False)
y = Bolivia_song_grpd['streams'].max()
Bolivia_song_grpd['streams_ratio'] = Bolivia_song_grpd['streams'].div(y).round(3)
Bolivia_song_grpd.sort_values(['streams_ratio'],ascending=False)

Bolivia_song_grpd['Popularity_Score'] = (Bolivia_song_grpd['WOC_ratio'] + Bolivia_song_grpd['rank_pts'] + Bolivia_song_grpd['streams_ratio'])/3

Bolivia_song_grpd.columns
Bolivia_best_songs = Bolivia_song_grpd[['artist_names', 'track_name', 'Popularity_Score', 'WOC_ratio', 'rank_pts',
       'streams_ratio','streams', 'rank', 'weeks_on_chart',
       'danceability', 'energy', 'loudness', 'speechiness', 'acousticness',
       'valence', 'tempo', 'duration','country']]
Bolivia_best_songs = Bolivia_best_songs.sort_values(['Popularity_Score'],ascending=False)
Bolivia_top_fifty = Bolivia_best_songs.head(50)
Bolivia_top_fifty.head(5)
# Out:
#                     artist_names       track_name  Popularity_Score  \
# 87      Bad Bunny, Bomba Estéreo    Ojitos Lindos          0.674778
# 89   Bad Bunny, Chencho Corleone  Me Porto Bonito          0.667888
# 71                     Bad Bunny      Moscow Mule          0.574000
# 230                  Danny Ocean        Me Rehúso          0.568863
# 64                     Bad Bunny           Efecto          0.560833
#
#      WOC_ratio  rank_pts  streams_ratio     streams    rank  weeks_on_chart  \
# 87       0.031  0.993335          1.000  301856.333   1.333             9.0
# 89       0.031  0.991665          0.981  296127.000   1.667             9.0
# 71       0.034  0.978000          0.710  214422.100   4.400            10.0
# 230      1.000  0.605590          0.101   30431.579  78.882           290.0
# 64       0.034  0.963500          0.685  206710.600   7.300            10.0
#
#      danceability  energy  loudness  speechiness  acousticness  valence  \
# 87          0.647   0.686    -5.745        0.041         0.080    0.268
# 89          0.911   0.712    -5.105        0.082         0.090    0.425
# 71          0.804   0.674    -5.453        0.033         0.294    0.292
# 230         0.744   0.804    -6.327        0.068         0.023    0.426
# 64          0.801   0.475    -8.797        0.052         0.141    0.234
#
#        tempo  duration  country
# 87    79.928     258.0  Bolivia
# 89    92.005     179.0  Bolivia
# 71    99.968     246.0  Bolivia
# 230  104.823     206.0  Bolivia
# 64    98.047     213.0  Bolivia

# %%
#Brazil Dataframe
# applying groupby() function to
# group the data on team value.
gk = music_df.groupby('country')
  
# Let's print the first entries
# in all the groups formed.
#gk.first()
Brazil_df = gk.get_group('Brazil')

Brazil_song_grpd = Brazil_df.groupby(['artist_names','track_name']).aggregate({'streams':'mean','rank':'mean','weeks_on_chart':'max','danceability':'mean', 'energy':'mean','loudness':'mean',
       'speechiness':'mean', 'acousticness':'mean','valence':'mean', 'tempo':'mean', 'duration':'mean'}).round(3)
Brazil_song_grpd = Brazil_song_grpd.reset_index() 
Brazil_song_grpd['country'] = 'Brazil'
       
Brazil_song_grpd.sort_values(['weeks_on_chart'],ascending=False)

x= Brazil_song_grpd['weeks_on_chart'].max()
Brazil_song_grpd['WOC_ratio'] = Brazil_song_grpd['weeks_on_chart'].div(x).round(3)
Brazil_song_grpd.head(5)

Brazil_song_grpd['rank'].max()
rank_pts = []
for row in Brazil_song_grpd['rank']:
    rank_pts.append((100 - (row * .5))/100)

Brazil_song_grpd['rank_pts'] = rank_pts
Brazil_song_grpd.head(5)

Brazil_song_grpd.sort_values(['streams'],ascending=False)
y = Brazil_song_grpd['streams'].max()
Brazil_song_grpd['streams_ratio'] = Brazil_song_grpd['streams'].div(y).round(3)
Brazil_song_grpd.sort_values(['streams_ratio'],ascending=False)

Brazil_song_grpd['Popularity_Score'] = (Brazil_song_grpd['WOC_ratio'] + Brazil_song_grpd['rank_pts'] + Brazil_song_grpd['streams_ratio'])/3

Brazil_song_grpd.columns
Brazil_best_songs = Brazil_song_grpd[['artist_names', 'track_name', 'Popularity_Score', 'WOC_ratio', 'rank_pts',
       'streams_ratio','streams', 'rank', 'weeks_on_chart',
       'danceability', 'energy', 'loudness', 'speechiness', 'acousticness',
       'valence', 'tempo', 'duration','country']]
Brazil_best_songs = Brazil_best_songs.sort_values(['Popularity_Score'],ascending=False)
Brazil_top_fifty = Brazil_best_songs.head(50)
Brazil_top_fifty.head(5)
# Out:
#                                            artist_names            track_name  \
# 1054                            Xamã, Gustah, Neo Beats            Malvadão 3
# 373                  Hugo & Guilherme, Marília Mendonça   Mal Feito - Ao Vivo
# 156   Davi Kneip, Mc Frog, Dj Gabriel do Borel, Luís...  sentaDONA (Remix) s2
# 345                                  Henrique & Juliano    Arranhão - Ao Vivo
# 905                          PEDRO SAMPAIO, Mc Pedrinho             DANÇARINA
#
#       Popularity_Score  WOC_ratio  rank_pts  streams_ratio      streams  \
# 1054          0.704198      0.199  0.913595          1.000  5342002.812
# 373           0.703897      0.161  0.967690          0.983  5250011.962
# 156           0.689588      0.106  0.971765          0.991  5293732.471
# 345           0.685062      0.304  0.914185          0.837  4471500.592
# 905           0.671595      0.143  0.929785          0.942  5030280.348
#
#         rank  weeks_on_chart  danceability  energy  loudness  speechiness  \
# 1054  17.281            32.0         0.821   0.609    -6.541        0.268
# 373    6.462            26.0         0.732   0.831    -3.791        0.069
# 156    5.647            17.0         0.925   0.454    -3.533        0.273
# 345   17.163            49.0         0.486   0.871    -3.642        0.258
# 905   14.043            23.0         0.778   0.571    -4.776        0.079
#
#       acousticness  valence    tempo  duration country
# 1054         0.378    0.516  133.133     142.0  Brazil
# 373          0.554    0.684  123.942     178.0  Brazil
# 156          0.252    0.771  135.020     125.0  Brazil
# 345          0.617    0.663  151.175     153.0  Brazil
# 905          0.042    0.554  134.999     110.0  Brazil

# %%
#Bulgaria Dataframe
# applying groupby() function to
# group the data on team value.
gk = music_df.groupby('country')
  
# Let's print the first entries
# in all the groups formed.
#gk.first()
Bulgaria_df = gk.get_group('Bulgaria')

Bulgaria_song_grpd = Bulgaria_df.groupby(['artist_names','track_name']).aggregate({'streams':'mean','rank':'mean','weeks_on_chart':'max','danceability':'mean', 'energy':'mean','loudness':'mean',
       'speechiness':'mean', 'acousticness':'mean','valence':'mean', 'tempo':'mean', 'duration':'mean'}).round(3)
Bulgaria_song_grpd = Bulgaria_song_grpd.reset_index() 
Bulgaria_song_grpd['country'] = 'Bulgaria'
       
Bulgaria_song_grpd.sort_values(['weeks_on_chart'],ascending=False)

x= Bulgaria_song_grpd['weeks_on_chart'].max()
Bulgaria_song_grpd['WOC_ratio'] = Bulgaria_song_grpd['weeks_on_chart'].div(x).round(3)
Bulgaria_song_grpd.head(5)

Bulgaria_song_grpd['rank'].max()
rank_pts = []
for row in Bulgaria_song_grpd['rank']:
    rank_pts.append((100 - (row * .5))/100)

Bulgaria_song_grpd['rank_pts'] = rank_pts
Bulgaria_song_grpd.head(5)

Bulgaria_song_grpd.sort_values(['streams'],ascending=False)
y = Bulgaria_song_grpd['streams'].max()
Bulgaria_song_grpd['streams_ratio'] = Bulgaria_song_grpd['streams'].div(y).round(3)
Bulgaria_song_grpd.sort_values(['streams_ratio'],ascending=False)

Bulgaria_song_grpd['Popularity_Score'] = (Bulgaria_song_grpd['WOC_ratio'] + Bulgaria_song_grpd['rank_pts'] + Bulgaria_song_grpd['streams_ratio'])/3

Bulgaria_song_grpd.columns
Bulgaria_best_songs = Bulgaria_song_grpd[['artist_names', 'track_name', 'Popularity_Score', 'WOC_ratio', 'rank_pts',
       'streams_ratio','streams', 'rank', 'weeks_on_chart',
       'danceability', 'energy', 'loudness', 'speechiness', 'acousticness',
       'valence', 'tempo', 'duration','country']]
Bulgaria_best_songs = Bulgaria_best_songs.sort_values(['Popularity_Score'],ascending=False)
Bulgaria_top_fifty = Bulgaria_best_songs.head(50)
Bulgaria_top_fifty.head(5)
# Out:
#                      artist_names             track_name  Popularity_Score  \
# 378                      Måneskin                Beggin'          0.676000
# 580  V:RGO, EMIL TRF, FYRE, 2bona                PARALIA          0.619583
# 382                      Måneskin  I WANNA BE YOUR SLAVE          0.612555
# 211                        Galena        Ти не си за мен          0.570000
# 552                  Travis Scott             goosebumps          0.559750
#
#      WOC_ratio  rank_pts  streams_ratio    streams    rank  weeks_on_chart  \
# 378      0.033  0.995000          1.000  58021.667   1.000             9.0
# 580      0.022  0.993750          0.843  48896.250   1.250             6.0
# 382      0.036  0.986665          0.815  47280.667   2.667            10.0
# 211      0.004  0.985000          0.721  41855.000   3.000             1.0
# 552      0.869  0.641250          0.169   9817.250  71.750           238.0
#
#      danceability  energy  loudness  speechiness  acousticness  valence  \
# 378         0.714   0.800    -4.808        0.050         0.127    0.589
# 580         0.817   0.647    -6.475        0.243         0.145    0.723
# 382         0.750   0.608    -4.008        0.039         0.002    0.958
# 211         0.607   0.779    -5.923        0.248         0.031    0.875
# 552         0.841   0.728    -3.370        0.048         0.085    0.430
#
#        tempo  duration   country
# 378  134.002     212.0  Bulgaria
# 580  142.981     274.0  Bulgaria
# 382  132.507     173.0  Bulgaria
# 211  169.966     217.0  Bulgaria
# 552  130.049     244.0  Bulgaria

# %%
#Canada Dataframe
# applying groupby() function to
# group the data on team value.
gk = music_df.groupby('country')
  
# Let's print the first entries
# in all the groups formed.
#gk.first()
Canada_df = gk.get_group('Canada')

Canada_song_grpd = Canada_df.groupby(['artist_names','track_name']).aggregate({'streams':'mean','rank':'mean','weeks_on_chart':'max','danceability':'mean', 'energy':'mean','loudness':'mean',
       'speechiness':'mean', 'acousticness':'mean','valence':'mean', 'tempo':'mean', 'duration':'mean'}).round(3)
Canada_song_grpd = Canada_song_grpd.reset_index() 
Canada_song_grpd['country'] = 'Canada'
       
Canada_song_grpd.sort_values(['weeks_on_chart'],ascending=False)

x= Canada_song_grpd['weeks_on_chart'].max()
Canada_song_grpd['WOC_ratio'] = Canada_song_grpd['weeks_on_chart'].div(x).round(3)
Canada_song_grpd.head(5)

Canada_song_grpd['rank'].max()
rank_pts = []
for row in Canada_song_grpd['rank']:
    rank_pts.append((100 - (row * .5))/100)

Canada_song_grpd['rank_pts'] = rank_pts
Canada_song_grpd.head(5)

Canada_song_grpd.sort_values(['streams'],ascending=False)
y = Canada_song_grpd['streams'].max()
Canada_song_grpd['streams_ratio'] = Canada_song_grpd['streams'].div(y).round(3)
Canada_song_grpd.sort_values(['streams_ratio'],ascending=False)

Canada_song_grpd['Popularity_Score'] = (Canada_song_grpd['WOC_ratio'] + Canada_song_grpd['rank_pts'] + Canada_song_grpd['streams_ratio'])/3

Canada_song_grpd.columns
Canada_best_songs = Canada_song_grpd[['artist_names', 'track_name', 'Popularity_Score', 'WOC_ratio', 'rank_pts',
       'streams_ratio','streams', 'rank', 'weeks_on_chart',
       'danceability', 'energy', 'loudness', 'speechiness', 'acousticness',
       'valence', 'tempo', 'duration','country']]
Canada_best_songs = Canada_best_songs.sort_values(['Popularity_Score'],ascending=False)
Canada_top_fifty = Canada_best_songs.head(50)
Canada_top_fifty.head(5)
# Out:
#                       artist_names  \
# 571                   Harry Styles
# 408               Drake, 21 Savage
# 785                      Kate Bush
# 1436  The Kid LAROI, Justin Bieber
# 630                    Jack Harlow
#
#                                              track_name  Popularity_Score  \
# 571                                           As It Was          0.673667
# 408                       Jimmy Cooks (feat. 21 Savage)          0.668750
# 785   Running Up That Hill (A Deal With God) - 2018 ...          0.621190
# 1436                          STAY (with Justin Bieber)          0.604428
# 630                                         First Class          0.601023
#
#       WOC_ratio  rank_pts  streams_ratio      streams   rank  weeks_on_chart  \
# 571       0.056  0.990000          0.975  1901046.467  2.000            15.0
# 408       0.015  0.991250          1.000  1949385.500  1.750             4.0
# 785       0.026  0.988570          0.849  1654389.857  2.286             7.0
# 1436      0.199  0.965285          0.649  1265152.396  6.943            53.0
# 630       0.053  0.976070          0.774  1509068.857  4.786            14.0
#
#       danceability  energy  loudness  speechiness  acousticness  valence  \
# 571          0.520   0.731    -5.338        0.056         0.342    0.662
# 408          0.529   0.673    -4.711        0.175         0.000    0.366
# 785          0.629   0.547   -13.123        0.055         0.720    0.197
# 1436         0.591   0.764    -5.484        0.048         0.038    0.478
# 630          0.903   0.577    -5.969        0.107         0.087    0.330
#
#         tempo  duration country
# 571   173.930     167.0  Canada
# 408   165.921     218.0  Canada
# 785   108.375     299.0  Canada
# 1436  169.928     142.0  Canada
# 630   107.003     174.0  Canada

# %%
#Chile Dataframe
# applying groupby() function to
# group the data on team value.
gk = music_df.groupby('country')
  
# Let's print the first entries
# in all the groups formed.
#gk.first()
Chile_df = gk.get_group('Chile')

Chile_song_grpd = Chile_df.groupby(['artist_names','track_name']).aggregate({'streams':'mean','rank':'mean','weeks_on_chart':'max','danceability':'mean', 'energy':'mean','loudness':'mean',
       'speechiness':'mean', 'acousticness':'mean','valence':'mean', 'tempo':'mean', 'duration':'mean'}).round(3)
Chile_song_grpd = Chile_song_grpd.reset_index() 
Chile_song_grpd['country'] = 'Chile'
       
Chile_song_grpd.sort_values(['weeks_on_chart'],ascending=False)

x= Chile_song_grpd['weeks_on_chart'].max()
Chile_song_grpd['WOC_ratio'] = Chile_song_grpd['weeks_on_chart'].div(x).round(3)
Chile_song_grpd.head(5)

Chile_song_grpd['rank'].max()
rank_pts = []
for row in Chile_song_grpd['rank']:
    rank_pts.append((100 - (row * .5))/100)

Chile_song_grpd['rank_pts'] = rank_pts
Chile_song_grpd.head(5)

Chile_song_grpd.sort_values(['streams'],ascending=False)
y = Chile_song_grpd['streams'].max()
Chile_song_grpd['streams_ratio'] = Chile_song_grpd['streams'].div(y).round(3)
Chile_song_grpd.sort_values(['streams_ratio'],ascending=False)

Chile_song_grpd['Popularity_Score'] = (Chile_song_grpd['WOC_ratio'] + Chile_song_grpd['rank_pts'] + Chile_song_grpd['streams_ratio'])/3

Chile_song_grpd.columns
Chile_best_songs = Chile_song_grpd[['artist_names', 'track_name', 'Popularity_Score', 'WOC_ratio', 'rank_pts',
       'streams_ratio','streams', 'rank', 'weeks_on_chart',
       'danceability', 'energy', 'loudness', 'speechiness', 'acousticness',
       'valence', 'tempo', 'duration','country']]
Chile_best_songs = Chile_best_songs.sort_values(['Popularity_Score'],ascending=False)
Chile_top_fifty = Chile_best_songs.head(50)
Chile_top_fifty.head(5)
# Out:
#                     artist_names       track_name  Popularity_Score  \
# 13      Ak4:20, Pailita, Cris Mj     Me Arrepentí          0.675208
# 110     Bad Bunny, Bomba Estéreo    Ojitos Lindos          0.639833
# 712    Polimá Westcoast, Pailita       ULTRA SOLO          0.615667
# 112  Bad Bunny, Chencho Corleone  Me Porto Bonito          0.615417
# 93                     Bad Bunny      Moscow Mule          0.586222
#
#      WOC_ratio  rank_pts  streams_ratio      streams   rank  weeks_on_chart  \
# 13       0.045  0.980625          1.000  3581153.750  3.875            12.0
# 110      0.023  0.992500          0.904  3236808.000  1.500             6.0
# 712      0.068  0.951000          0.828  2964101.900  9.800            18.0
# 112      0.023  0.986250          0.837  2998915.500  2.750             6.0
# 93       0.038  0.976665          0.744  2664859.333  4.667            10.0
#
#      danceability  energy  loudness  speechiness  acousticness  valence  \
# 13          0.861   0.786    -4.934        0.164         0.289    0.907
# 110         0.647   0.686    -5.745        0.041         0.080    0.268
# 712         0.802   0.846    -4.495        0.207         0.233    0.260
# 112         0.911   0.712    -5.105        0.082         0.090    0.425
# 93          0.804   0.674    -5.453        0.033         0.294    0.292
#
#        tempo  duration country
# 13    92.031     232.0   Chile
# 110   79.928     258.0   Chile
# 712  109.982     227.0   Chile
# 112   92.005     179.0   Chile
# 93    99.968     246.0   Chile

# %%
#Colombia Dataframe
# applying groupby() function to
# group the data on team value.
gk = music_df.groupby('country')
  
# Let's print the first entries
# in all the groups formed.
#gk.first()
Colombia_df = gk.get_group('Colombia')

Colombia_song_grpd = Colombia_df.groupby(['artist_names','track_name']).aggregate({'streams':'mean','rank':'mean','weeks_on_chart':'max','danceability':'mean', 'energy':'mean','loudness':'mean',
       'speechiness':'mean', 'acousticness':'mean','valence':'mean', 'tempo':'mean', 'duration':'mean'}).round(3)
Colombia_song_grpd = Colombia_song_grpd.reset_index() 
Colombia_song_grpd['country'] = 'Colombia'
       
Colombia_song_grpd.sort_values(['weeks_on_chart'],ascending=False)

x= Colombia_song_grpd['weeks_on_chart'].max()
Colombia_song_grpd['WOC_ratio'] = Colombia_song_grpd['weeks_on_chart'].div(x).round(3)
Colombia_song_grpd.head(5)

Colombia_song_grpd['rank'].max()
rank_pts = []
for row in Colombia_song_grpd['rank']:
    rank_pts.append((100 - (row * .5))/100)

Colombia_song_grpd['rank_pts'] = rank_pts
Colombia_song_grpd.head(5)

Colombia_song_grpd.sort_values(['streams'],ascending=False)
y = Colombia_song_grpd['streams'].max()
Colombia_song_grpd['streams_ratio'] = Colombia_song_grpd['streams'].div(y).round(3)
Colombia_song_grpd.sort_values(['streams_ratio'],ascending=False)

Colombia_song_grpd['Popularity_Score'] = (Colombia_song_grpd['WOC_ratio'] + Colombia_song_grpd['rank_pts'] + Colombia_song_grpd['streams_ratio'])/3

Colombia_song_grpd.columns
Colombia_best_songs = Colombia_song_grpd[['artist_names', 'track_name', 'Popularity_Score', 'WOC_ratio', 'rank_pts',
       'streams_ratio','streams', 'rank', 'weeks_on_chart',
       'danceability', 'energy', 'loudness', 'speechiness', 'acousticness',
       'valence', 'tempo', 'duration','country']]
Colombia_best_songs = Colombia_best_songs.sort_values(['Popularity_Score'],ascending=False)
Colombia_top_fifty = Colombia_best_songs.head(50)
Colombia_top_fifty.head(5)
# Out:
#                     artist_names        track_name  Popularity_Score  \
# 94   Bad Bunny, Chencho Corleone   Me Porto Bonito          0.675667
# 92      Bad Bunny, Bomba Estéreo     Ojitos Lindos          0.645000
# 83                     Bad Bunny  Tití Me Preguntó          0.582333
# 76                     Bad Bunny       Moscow Mule          0.580250
# 424                      KAROL G          PROVENZA          0.576667
#
#      WOC_ratio  rank_pts  streams_ratio     streams  rank  weeks_on_chart  \
# 94       0.035   0.99200          1.000  1898486.40  1.60            10.0
# 92       0.035   0.99000          0.910  1727154.40  2.00            10.0
# 83       0.021   0.98000          0.746  1416392.75  4.00             6.0
# 76       0.021   0.97875          0.741  1406307.25  4.25             6.0
# 424      0.028   0.98200          0.720  1367417.80  3.60             8.0
#
#      danceability  energy  loudness  speechiness  acousticness  valence  \
# 94          0.911   0.712    -5.105        0.082         0.090    0.425
# 92          0.647   0.686    -5.745        0.041         0.080    0.268
# 83          0.650   0.715    -5.198        0.253         0.099    0.187
# 76          0.804   0.674    -5.453        0.033         0.294    0.292
# 424         0.870   0.516    -8.006        0.054         0.656    0.530
#
#        tempo  duration   country
# 94    92.005     179.0  Colombia
# 92    79.928     258.0  Colombia
# 83   106.672     244.0  Colombia
# 76    99.968     246.0  Colombia
# 424  111.005     210.0  Colombia

# %%
#Costa_Rica Dataframe
# applying groupby() function to
# group the data on team value.
gk = music_df.groupby('country')
  
# Let's print the first entries
# in all the groups formed.
#gk.first()
Costa_Rica_df = gk.get_group('Costa Rica')

Costa_Rica_song_grpd = Costa_Rica_df.groupby(['artist_names','track_name']).aggregate({'streams':'mean','rank':'mean','weeks_on_chart':'max','danceability':'mean', 'energy':'mean','loudness':'mean',
       'speechiness':'mean', 'acousticness':'mean','valence':'mean', 'tempo':'mean', 'duration':'mean'}).round(3)
Costa_Rica_song_grpd = Costa_Rica_song_grpd.reset_index() 
Costa_Rica_song_grpd['country'] = 'Costa_Rica'
       
Costa_Rica_song_grpd.sort_values(['weeks_on_chart'],ascending=False)

x= Costa_Rica_song_grpd['weeks_on_chart'].max()
Costa_Rica_song_grpd['WOC_ratio'] = Costa_Rica_song_grpd['weeks_on_chart'].div(x).round(3)
Costa_Rica_song_grpd.head(5)

Costa_Rica_song_grpd['rank'].max()
rank_pts = []
for row in Costa_Rica_song_grpd['rank']:
    rank_pts.append((100 - (row * .5))/100)

Costa_Rica_song_grpd['rank_pts'] = rank_pts
Costa_Rica_song_grpd.head(5)

Costa_Rica_song_grpd.sort_values(['streams'],ascending=False)
y = Costa_Rica_song_grpd['streams'].max()
Costa_Rica_song_grpd['streams_ratio'] = Costa_Rica_song_grpd['streams'].div(y).round(3)
Costa_Rica_song_grpd.sort_values(['streams_ratio'],ascending=False)

Costa_Rica_song_grpd['Popularity_Score'] = (Costa_Rica_song_grpd['WOC_ratio'] + Costa_Rica_song_grpd['rank_pts'] + Costa_Rica_song_grpd['streams_ratio'])/3

Costa_Rica_song_grpd.columns
Costa_Rica_best_songs = Costa_Rica_song_grpd[['artist_names', 'track_name', 'Popularity_Score', 'WOC_ratio', 'rank_pts',
       'streams_ratio','streams', 'rank', 'weeks_on_chart',
       'danceability', 'energy', 'loudness', 'speechiness', 'acousticness',
       'valence', 'tempo', 'duration','country']]
Costa_Rica_best_songs = Costa_Rica_best_songs.sort_values(['Popularity_Score'],ascending=False)
Costa_Rica_top_fifty = Costa_Rica_best_songs.head(50)
Costa_Rica_top_fifty.head(5)
# Out:
#                     artist_names                             track_name  \
# 114     Bad Bunny, Bomba Estéreo                          Ojitos Lindos
# 104                    Bad Bunny                       Tití Me Preguntó
# 116  Bad Bunny, Chencho Corleone                        Me Porto Bonito
# 153            Bizarrap, Quevedo  Quevedo: Bzrp Music Sessions, Vol. 52
# 94                     Bad Bunny                            Moscow Mule
#
#      Popularity_Score  WOC_ratio  rank_pts  streams_ratio   streams  rank  \
# 114          0.674167      0.035    0.9875          1.000  506965.5   2.5
# 104          0.658333      0.035    0.9930          0.947  480129.4   1.4
# 116          0.633000      0.035    0.9850          0.879  445856.0   3.0
# 153          0.571667      0.007    0.9850          0.723  366524.0   3.0
# 94           0.565500      0.035    0.9785          0.683  346364.3   4.3
#
#      weeks_on_chart  danceability  energy  loudness  speechiness  \
# 114            10.0         0.647   0.686    -5.745        0.041
# 104            10.0         0.650   0.715    -5.198        0.253
# 116            10.0         0.911   0.712    -5.105        0.082
# 153             2.0         0.621   0.782    -5.548        0.044
# 94             10.0         0.804   0.674    -5.453        0.033
#
#      acousticness  valence    tempo  duration     country
# 114         0.080    0.268   79.928     258.0  Costa_Rica
# 104         0.099    0.187  106.672     244.0  Costa_Rica
# 116         0.090    0.425   92.005     179.0  Costa_Rica
# 153         0.012    0.550  128.033     199.0  Costa_Rica
# 94          0.294    0.292   99.968     246.0  Costa_Rica

# %%
#Cyprus Dataframe
# applying groupby() function to
# group the data on team value.
gk = music_df.groupby('country')
  
# Let's print the first entries
# in all the groups formed.
#gk.first()
Cyprus_df = gk.get_group('Cyprus')

Cyprus_song_grpd = Cyprus_df.groupby(['artist_names','track_name']).aggregate({'streams':'mean','rank':'mean','weeks_on_chart':'max','danceability':'mean', 'energy':'mean','loudness':'mean',
       'speechiness':'mean', 'acousticness':'mean','valence':'mean', 'tempo':'mean', 'duration':'mean'}).round(3)
Cyprus_song_grpd = Cyprus_song_grpd.reset_index() 
Cyprus_song_grpd['country'] = 'Cyprus'
       
Cyprus_song_grpd.sort_values(['weeks_on_chart'],ascending=False)

x= Cyprus_song_grpd['weeks_on_chart'].max()
Cyprus_song_grpd['WOC_ratio'] = Cyprus_song_grpd['weeks_on_chart'].div(x).round(3)
Cyprus_song_grpd.head(5)

Cyprus_song_grpd['rank'].max()
rank_pts = []
for row in Cyprus_song_grpd['rank']:
    rank_pts.append((100 - (row * .5))/100)

Cyprus_song_grpd['rank_pts'] = rank_pts
Cyprus_song_grpd.head(5)

Cyprus_song_grpd.sort_values(['streams'],ascending=False)
y = Cyprus_song_grpd['streams'].max()
Cyprus_song_grpd['streams_ratio'] = Cyprus_song_grpd['streams'].div(y).round(3)
Cyprus_song_grpd.sort_values(['streams_ratio'],ascending=False)

Cyprus_song_grpd['Popularity_Score'] = (Cyprus_song_grpd['WOC_ratio'] + Cyprus_song_grpd['rank_pts'] + Cyprus_song_grpd['streams_ratio'])/3

Cyprus_song_grpd.columns
Cyprus_best_songs = Cyprus_song_grpd[['artist_names', 'track_name', 'Popularity_Score', 'WOC_ratio', 'rank_pts',
       'streams_ratio','streams', 'rank', 'weeks_on_chart',
       'danceability', 'energy', 'loudness', 'speechiness', 'acousticness',
       'valence', 'tempo', 'duration','country']]
Cyprus_best_songs = Cyprus_best_songs.sort_values(['Popularity_Score'],ascending=False)
Cyprus_top_fifty = Cyprus_best_songs.head(50)
Cyprus_top_fifty.head(5)
# Out:
#                artist_names track_name  Popularity_Score  WOC_ratio  rank_pts  \
# 766          Light, Trannos      24hrs          0.670333      0.016     0.995
# 441      Fy, Light, Trannos   Obsessed          0.562000      0.004     0.990
# 759  Light, Melisses, Skive   Epiloges          0.543333      0.004     0.985
# 483            Harry Styles  As It Was          0.502000      0.061     0.985
# 686          Kings, Trannos     Madame          0.492000      0.053     0.975
#
#      streams_ratio    streams  rank  weeks_on_chart  danceability  energy  \
# 766          1.000  55361.500   1.0             4.0         0.746   0.662
# 441          0.692  38336.000   2.0             1.0         0.797   0.680
# 759          0.641  35514.000   3.0             1.0         0.552   0.433
# 483          0.460  25473.733   3.0            15.0         0.520   0.731
# 686          0.448  24824.769   5.0            13.0         0.809   0.961
#
#      loudness  speechiness  acousticness  valence    tempo  duration country
# 766    -6.706        0.088         0.069    0.680  102.024     175.0  Cyprus
# 441    -8.628        0.103         0.048    0.593  145.092     217.0  Cyprus
# 759    -9.586        0.385         0.320    0.312  150.608     223.0  Cyprus
# 483    -5.338        0.056         0.342    0.662  173.930     167.0  Cyprus
# 686    -2.910        0.041         0.061    0.865  122.032     185.0  Cyprus

# %%
#Czech_Republic Dataframe
# applying groupby() function to
# group the data on team value.
gk = music_df.groupby('country')
  
# Let's print the first entries
# in all the groups formed.
#gk.first()
Czech_Republic_df = gk.get_group('Czech Republic')

Czech_Republic_song_grpd = Czech_Republic_df.groupby(['artist_names','track_name']).aggregate({'streams':'mean','rank':'mean','weeks_on_chart':'max','danceability':'mean', 'energy':'mean','loudness':'mean',
       'speechiness':'mean', 'acousticness':'mean','valence':'mean', 'tempo':'mean', 'duration':'mean'}).round(3)
Czech_Republic_song_grpd = Czech_Republic_song_grpd.reset_index() 
Czech_Republic_song_grpd['country'] = 'Czech_Republic'
       
Czech_Republic_song_grpd.sort_values(['weeks_on_chart'],ascending=False)

x= Czech_Republic_song_grpd['weeks_on_chart'].max()
Czech_Republic_song_grpd['WOC_ratio'] = Czech_Republic_song_grpd['weeks_on_chart'].div(x).round(3)
Czech_Republic_song_grpd.head(5)

Czech_Republic_song_grpd['rank'].max()
rank_pts = []
for row in Czech_Republic_song_grpd['rank']:
    rank_pts.append((100 - (row * .5))/100)

Czech_Republic_song_grpd['rank_pts'] = rank_pts
Czech_Republic_song_grpd.head(5)

Czech_Republic_song_grpd.sort_values(['streams'],ascending=False)
y = Czech_Republic_song_grpd['streams'].max()
Czech_Republic_song_grpd['streams_ratio'] = Czech_Republic_song_grpd['streams'].div(y).round(3)
Czech_Republic_song_grpd.sort_values(['streams_ratio'],ascending=False)

Czech_Republic_song_grpd['Popularity_Score'] = (Czech_Republic_song_grpd['WOC_ratio'] + Czech_Republic_song_grpd['rank_pts'] + Czech_Republic_song_grpd['streams_ratio'])/3

Czech_Republic_song_grpd.columns
Czech_Republic_best_songs = Czech_Republic_song_grpd[['artist_names', 'track_name', 'Popularity_Score', 'WOC_ratio', 'rank_pts',
       'streams_ratio','streams', 'rank', 'weeks_on_chart',
       'danceability', 'energy', 'loudness', 'speechiness', 'acousticness',
       'valence', 'tempo', 'duration','country']]
Czech_Republic_best_songs = Czech_Republic_best_songs.sort_values(['Popularity_Score'],ascending=False)
Czech_Republic_top_fifty = Czech_Republic_best_songs.head(50)
Czech_Republic_top_fifty.head(5)
# Out:
#                               artist_names                       track_name  \
# 95                                   Calin                   Hannah Montana
# 815                                Wohnout              Svaz ceskych bohemu
# 483                           Mariah Carey  All I Want for Christmas Is You
# 814                                  Wham!                   Last Christmas
# 801  Viktor Sheen, Calin, Hasan, Nik Tendo                      Až na měsíc
#
#      Popularity_Score  WOC_ratio  rank_pts  streams_ratio     streams    rank  \
# 95           0.681667      0.050  0.995000          1.000  423591.444   1.000
# 815          0.623523      0.982  0.740570          0.148   62596.571  51.886
# 483          0.569333      0.133  0.985000          0.590  250092.000   3.000
# 814          0.555555      0.118  0.976665          0.572  242272.667   4.667
# 801          0.555000      0.591  0.875000          0.199   84245.818  25.000
#
#      weeks_on_chart  danceability  energy  loudness  speechiness  \
# 95             14.0         0.583   0.784    -6.708        0.088
# 815           274.0         0.673   0.790    -6.989        0.042
# 483            37.0         0.336   0.627    -7.463        0.038
# 814            33.0         0.735   0.478   -12.472        0.029
# 801           165.0         0.744   0.571   -10.409        0.064
#
#      acousticness  valence    tempo  duration         country
# 95          0.062    0.744  135.080     159.0  Czech_Republic
# 815         0.030    0.514  117.992     257.0  Czech_Republic
# 483         0.164    0.350  150.273     241.0  Czech_Republic
# 814         0.189    0.947  107.682     263.0  Czech_Republic
# 801         0.266    0.535  115.088     209.0  Czech_Republic

# %%
#Denmark Dataframe
# applying groupby() function to
# group the data on team value.
gk = music_df.groupby('country')
  
# Let's print the first entries
# in all the groups formed.
#gk.first()
Denmark_df = gk.get_group('Denmark')

Denmark_song_grpd = Denmark_df.groupby(['artist_names','track_name']).aggregate({'streams':'mean','rank':'mean','weeks_on_chart':'max','danceability':'mean', 'energy':'mean','loudness':'mean',
       'speechiness':'mean', 'acousticness':'mean','valence':'mean', 'tempo':'mean', 'duration':'mean'}).round(3)
Denmark_song_grpd = Denmark_song_grpd.reset_index() 
Denmark_song_grpd['country'] = 'Denmark'
       
Denmark_song_grpd.sort_values(['weeks_on_chart'],ascending=False)

x= Denmark_song_grpd['weeks_on_chart'].max()
Denmark_song_grpd['WOC_ratio'] = Denmark_song_grpd['weeks_on_chart'].div(x).round(3)
Denmark_song_grpd.head(5)

Denmark_song_grpd['rank'].max()
rank_pts = []
for row in Denmark_song_grpd['rank']:
    rank_pts.append((100 - (row * .5))/100)

Denmark_song_grpd['rank_pts'] = rank_pts
Denmark_song_grpd.head(5)

Denmark_song_grpd.sort_values(['streams'],ascending=False)
y = Denmark_song_grpd['streams'].max()
Denmark_song_grpd['streams_ratio'] = Denmark_song_grpd['streams'].div(y).round(3)
Denmark_song_grpd.sort_values(['streams_ratio'],ascending=False)

Denmark_song_grpd['Popularity_Score'] = (Denmark_song_grpd['WOC_ratio'] + Denmark_song_grpd['rank_pts'] + Denmark_song_grpd['streams_ratio'])/3

Denmark_song_grpd.columns
Denmark_best_songs = Denmark_song_grpd[['artist_names', 'track_name', 'Popularity_Score', 'WOC_ratio', 'rank_pts',
       'streams_ratio','streams', 'rank', 'weeks_on_chart',
       'danceability', 'energy', 'loudness', 'speechiness', 'acousticness',
       'valence', 'tempo', 'duration','country']]
Denmark_best_songs = Denmark_best_songs.sort_values(['Popularity_Score'],ascending=False)
Denmark_top_fifty = Denmark_best_songs.head(50)
Denmark_top_fifty.head(5)
# Out:
#                         artist_names                         track_name  \
# 1515                    Tobias Rahim              Feberdrømmer Xx Dubai
# 1522   Tobias Rahim, andreas odbjerg  STOR MAND (feat. Andreas Odbjerg)
# 1517                    Tobias Rahim                          Mucki Bar
# 105                Artigeardit, KESI        Er Her (Artigeardit X KESI)
# 162   Benny Jamz, Gilli, KESI, B.O.C                              Ibiza
#
#       Popularity_Score  WOC_ratio  rank_pts  streams_ratio     streams  \
# 1515          0.673667      0.026  0.995000          1.000  906656.667
# 1522          0.615305      0.204  0.982915          0.659  597572.438
# 1517          0.590863      0.094  0.991590          0.687  622967.364
# 105           0.559167      0.009  0.992500          0.676  612774.500
# 162           0.531512      0.238  0.925535          0.431  390528.750
#
#         rank  weeks_on_chart  danceability  energy  loudness  speechiness  \
# 1515   1.000             6.0         0.710   0.628    -6.661        0.048
# 1522   3.417            48.0         0.660   0.666    -6.150        0.051
# 1517   1.682            22.0         0.780   0.718    -6.622        0.034
# 105    1.500             2.0         0.589   0.706    -5.033        0.312
# 162   14.893            56.0         0.882   0.727    -6.539        0.259
#
#       acousticness  valence    tempo  duration  country
# 1515         0.197    0.462  135.990     221.0  Denmark
# 1522         0.178    0.503  145.916     184.0  Denmark
# 1517         0.140    0.795  136.952     180.0  Denmark
# 105          0.151    0.711  125.546     157.0  Denmark
# 162          0.125    0.407  133.131     219.0  Denmark

# %%
#Dominican_Republic Dataframe
# applying groupby() function to
# group the data on team value.
gk = music_df.groupby('country')
  
# Let's print the first entries
# in all the groups formed.
#gk.first()
Dominican_Republic_df = gk.get_group('Dominican Republic')

Dominican_Republic_song_grpd = Dominican_Republic_df.groupby(['artist_names','track_name']).aggregate({'streams':'mean','rank':'mean','weeks_on_chart':'max','danceability':'mean', 'energy':'mean','loudness':'mean',
       'speechiness':'mean', 'acousticness':'mean','valence':'mean', 'tempo':'mean', 'duration':'mean'}).round(3)
Dominican_Republic_song_grpd = Dominican_Republic_song_grpd.reset_index() 
Dominican_Republic_song_grpd['country'] = 'Dominican_Republic'
       
Dominican_Republic_song_grpd.sort_values(['weeks_on_chart'],ascending=False)

x= Dominican_Republic_song_grpd['weeks_on_chart'].max()
Dominican_Republic_song_grpd['WOC_ratio'] = Dominican_Republic_song_grpd['weeks_on_chart'].div(x).round(3)
Dominican_Republic_song_grpd.head(5)

Dominican_Republic_song_grpd['rank'].max()
rank_pts = []
for row in Dominican_Republic_song_grpd['rank']:
    rank_pts.append((100 - (row * .5))/100)

Dominican_Republic_song_grpd['rank_pts'] = rank_pts
Dominican_Republic_song_grpd.head(5)

Dominican_Republic_song_grpd.sort_values(['streams'],ascending=False)
y = Dominican_Republic_song_grpd['streams'].max()
Dominican_Republic_song_grpd['streams_ratio'] = Dominican_Republic_song_grpd['streams'].div(y).round(3)
Dominican_Republic_song_grpd.sort_values(['streams_ratio'],ascending=False)

Dominican_Republic_song_grpd['Popularity_Score'] = (Dominican_Republic_song_grpd['WOC_ratio'] + Dominican_Republic_song_grpd['rank_pts'] + Dominican_Republic_song_grpd['streams_ratio'])/3

Dominican_Republic_song_grpd.columns
Dominican_Republic_best_songs = Dominican_Republic_song_grpd[['artist_names', 'track_name', 'Popularity_Score', 'WOC_ratio', 'rank_pts',
       'streams_ratio','streams', 'rank', 'weeks_on_chart',
       'danceability', 'energy', 'loudness', 'speechiness', 'acousticness',
       'valence', 'tempo', 'duration','country']]
Dominican_Republic_best_songs = Dominican_Republic_best_songs.sort_values(['Popularity_Score'],ascending=False)
Dominican_Republic_top_fifty = Dominican_Republic_best_songs.head(50)
Dominican_Republic_top_fifty.head(5)
# Out:
#                     artist_names        track_name  Popularity_Score  \
# 140                    Bad Bunny  Tití Me Preguntó          0.681833
# 154  Bad Bunny, Chencho Corleone   Me Porto Bonito          0.600888
# 128                    Bad Bunny       Moscow Mule          0.592167
# 151     Bad Bunny, Bomba Estéreo     Ojitos Lindos          0.554445
# 521          J Balvin, Bad Bunny        LA CANCIÓN          0.552222
#
#      WOC_ratio  rank_pts  streams_ratio     streams    rank  weeks_on_chart  \
# 140      0.052  0.993500          1.000  393835.100   1.300            10.0
# 154      0.042  0.991665          0.769  302735.000   1.667             8.0
# 128      0.052  0.984500          0.740  291438.100   3.100            10.0
# 151      0.042  0.983335          0.638  251156.000   3.333             8.0
# 521      0.818  0.751665          0.087   34095.083  49.667           157.0
#
#      danceability  energy  loudness  speechiness  acousticness  valence  \
# 140         0.650   0.715    -5.198        0.253         0.099    0.187
# 154         0.911   0.712    -5.105        0.082         0.090    0.425
# 128         0.804   0.674    -5.453        0.033         0.294    0.292
# 151         0.647   0.686    -5.745        0.041         0.080    0.268
# 521         0.754   0.646    -5.795        0.317         0.152    0.429
#
#        tempo  duration             country
# 140  106.672     244.0  Dominican_Republic
# 154   92.005     179.0  Dominican_Republic
# 128   99.968     246.0  Dominican_Republic
# 151   79.928     258.0  Dominican_Republic
# 521  176.089     243.0  Dominican_Republic

# %%
#Ecuador Dataframe
# applying groupby() function to
# group the data on team value.
gk = music_df.groupby('country')
  
# Let's print the first entries
# in all the groups formed.
#gk.first()
Ecuador_df = gk.get_group('Ecuador')

Ecuador_song_grpd = Ecuador_df.groupby(['artist_names','track_name']).aggregate({'streams':'mean','rank':'mean','weeks_on_chart':'max','danceability':'mean', 'energy':'mean','loudness':'mean',
       'speechiness':'mean', 'acousticness':'mean','valence':'mean', 'tempo':'mean', 'duration':'mean'}).round(3)
Ecuador_song_grpd = Ecuador_song_grpd.reset_index() 
Ecuador_song_grpd['country'] = 'Ecuador'
       
Ecuador_song_grpd.sort_values(['weeks_on_chart'],ascending=False)

x= Ecuador_song_grpd['weeks_on_chart'].max()
Ecuador_song_grpd['WOC_ratio'] = Ecuador_song_grpd['weeks_on_chart'].div(x).round(3)
Ecuador_song_grpd.head(5)

Ecuador_song_grpd['rank'].max()
rank_pts = []
for row in Ecuador_song_grpd['rank']:
    rank_pts.append((100 - (row * .5))/100)

Ecuador_song_grpd['rank_pts'] = rank_pts
Ecuador_song_grpd.head(5)

Ecuador_song_grpd.sort_values(['streams'],ascending=False)
y = Ecuador_song_grpd['streams'].max()
Ecuador_song_grpd['streams_ratio'] = Ecuador_song_grpd['streams'].div(y).round(3)
Ecuador_song_grpd.sort_values(['streams_ratio'],ascending=False)

Ecuador_song_grpd['Popularity_Score'] = (Ecuador_song_grpd['WOC_ratio'] + Ecuador_song_grpd['rank_pts'] + Ecuador_song_grpd['streams_ratio'])/3

Ecuador_song_grpd.columns
Ecuador_best_songs = Ecuador_song_grpd[['artist_names', 'track_name', 'Popularity_Score', 'WOC_ratio', 'rank_pts',
       'streams_ratio','streams', 'rank', 'weeks_on_chart',
       'danceability', 'energy', 'loudness', 'speechiness', 'acousticness',
       'valence', 'tempo', 'duration','country']]
Ecuador_best_songs = Ecuador_best_songs.sort_values(['Popularity_Score'],ascending=False)
Ecuador_top_fifty = Ecuador_best_songs.head(50)
Ecuador_top_fifty.head(5)
# Out:
#                     artist_names        track_name  Popularity_Score  \
# 103  Bad Bunny, Chencho Corleone   Me Porto Bonito          0.674333
# 101     Bad Bunny, Bomba Estéreo     Ojitos Lindos          0.613555
# 92                     Bad Bunny  Tití Me Preguntó          0.593833
# 79                     Bad Bunny       Moscow Mule          0.578333
# 69                     Bad Bunny            Efecto          0.578167
#
#      WOC_ratio  rank_pts  streams_ratio     streams   rank  weeks_on_chart  \
# 103      0.028  0.995000          1.000  883305.000  1.000             8.0
# 101      0.028  0.986665          0.826  729852.667  2.667             8.0
# 92       0.034  0.981500          0.766  676864.600  3.700            10.0
# 79       0.034  0.977000          0.724  639907.600  4.600            10.0
# 69       0.034  0.973500          0.727  641921.800  5.300            10.0
#
#      danceability  energy  loudness  speechiness  acousticness  valence  \
# 103         0.911   0.712    -5.105        0.082         0.090    0.425
# 101         0.647   0.686    -5.745        0.041         0.080    0.268
# 92          0.650   0.715    -5.198        0.253         0.099    0.187
# 79          0.804   0.674    -5.453        0.033         0.294    0.292
# 69          0.801   0.475    -8.797        0.052         0.141    0.234
#
#        tempo  duration  country
# 103   92.005     179.0  Ecuador
# 101   79.928     258.0  Ecuador
# 92   106.672     244.0  Ecuador
# 79    99.968     246.0  Ecuador
# 69    98.047     213.0  Ecuador

# %%
#Egypt Dataframe
# applying groupby() function to
# group the data on team value.
gk = music_df.groupby('country')
  
# Let's print the first entries
# in all the groups formed.
#gk.first()
Egypt_df = gk.get_group('Egypt')

Egypt_song_grpd = Egypt_df.groupby(['artist_names','track_name']).aggregate({'streams':'mean','rank':'mean','weeks_on_chart':'max','danceability':'mean', 'energy':'mean','loudness':'mean',
       'speechiness':'mean', 'acousticness':'mean','valence':'mean', 'tempo':'mean', 'duration':'mean'}).round(3)
Egypt_song_grpd = Egypt_song_grpd.reset_index() 
Egypt_song_grpd['country'] = 'Egypt'
       
Egypt_song_grpd.sort_values(['weeks_on_chart'],ascending=False)

x= Egypt_song_grpd['weeks_on_chart'].max()
Egypt_song_grpd['WOC_ratio'] = Egypt_song_grpd['weeks_on_chart'].div(x).round(3)
Egypt_song_grpd.head(5)

Egypt_song_grpd['rank'].max()
rank_pts = []
for row in Egypt_song_grpd['rank']:
    rank_pts.append((100 - (row * .5))/100)

Egypt_song_grpd['rank_pts'] = rank_pts
Egypt_song_grpd.head(5)

Egypt_song_grpd.sort_values(['streams'],ascending=False)
y = Egypt_song_grpd['streams'].max()
Egypt_song_grpd['streams_ratio'] = Egypt_song_grpd['streams'].div(y).round(3)
Egypt_song_grpd.sort_values(['streams_ratio'],ascending=False)

Egypt_song_grpd['Popularity_Score'] = (Egypt_song_grpd['WOC_ratio'] + Egypt_song_grpd['rank_pts'] + Egypt_song_grpd['streams_ratio'])/3

Egypt_song_grpd.columns
Egypt_best_songs = Egypt_song_grpd[['artist_names', 'track_name', 'Popularity_Score', 'WOC_ratio', 'rank_pts',
       'streams_ratio','streams', 'rank', 'weeks_on_chart',
       'danceability', 'energy', 'loudness', 'speechiness', 'acousticness',
       'valence', 'tempo', 'duration','country']]
Egypt_best_songs = Egypt_best_songs.sort_values(['Popularity_Score'],ascending=False)
Egypt_top_fifty = Egypt_best_songs.head(50)
Egypt_top_fifty.head(5)
# Out:
#               artist_names    track_name  Popularity_Score  WOC_ratio  \
# 868                   Wegz         البخت          0.699917      0.105
# 587           Marwan Pablo       Sindbad          0.570223      0.791
# 878                   Wegz         سكرتي          0.566382      0.743
# 564          Marwan Moussa  البوصلة ضاعت          0.562513      0.754
# 590  Marwan Pablo, Molotof          Free          0.558088      0.738
#
#      rank_pts  streams_ratio     streams    rank  weeks_on_chart  \
# 868  0.994750          1.000  316244.400   1.050            20.0
# 587  0.819670          0.100   31602.276  36.066           151.0
# 878  0.844145          0.112   35315.776  31.171           142.0
# 564  0.824540          0.109   34600.171  35.092           144.0
# 590  0.830265          0.106   33493.079  33.947           141.0
#
#      danceability  energy  loudness  speechiness  acousticness  valence  \
# 868         0.780   0.590    -7.770        0.132         0.487    0.660
# 587         0.751   0.774    -7.633        0.142         0.105    0.603
# 878         0.768   0.505   -10.115        0.350         0.652    0.357
# 564         0.753   0.504   -10.196        0.132         0.666    0.299
# 590         0.423   0.849    -3.782        0.143         0.125    0.312
#
#        tempo  duration country
# 868  104.977     206.0   Egypt
# 587  134.998     219.0   Egypt
# 878  140.080     211.0   Egypt
# 564  107.064     210.0   Egypt
# 590  116.956     218.0   Egypt

# %%
#El_Salvador Dataframe
# applying groupby() function to
# group the data on team value.
gk = music_df.groupby('country')
  
# Let's print the first entries
# in all the groups formed.
#gk.first()
El_Salvador_df = gk.get_group('El Salvador')

El_Salvador_song_grpd = El_Salvador_df.groupby(['artist_names','track_name']).aggregate({'streams':'mean','rank':'mean','weeks_on_chart':'max','danceability':'mean', 'energy':'mean','loudness':'mean',
       'speechiness':'mean', 'acousticness':'mean','valence':'mean', 'tempo':'mean', 'duration':'mean'}).round(3)
El_Salvador_song_grpd = El_Salvador_song_grpd.reset_index() 
El_Salvador_song_grpd['country'] = 'El_Salvador'
       
El_Salvador_song_grpd.sort_values(['weeks_on_chart'],ascending=False)

x= El_Salvador_song_grpd['weeks_on_chart'].max()
El_Salvador_song_grpd['WOC_ratio'] = El_Salvador_song_grpd['weeks_on_chart'].div(x).round(3)
El_Salvador_song_grpd.head(5)

El_Salvador_song_grpd['rank'].max()
rank_pts = []
for row in El_Salvador_song_grpd['rank']:
    rank_pts.append((100 - (row * .5))/100)

El_Salvador_song_grpd['rank_pts'] = rank_pts
El_Salvador_song_grpd.head(5)

El_Salvador_song_grpd.sort_values(['streams'],ascending=False)
y = El_Salvador_song_grpd['streams'].max()
El_Salvador_song_grpd['streams_ratio'] = El_Salvador_song_grpd['streams'].div(y).round(3)
El_Salvador_song_grpd.sort_values(['streams_ratio'],ascending=False)

El_Salvador_song_grpd['Popularity_Score'] = (El_Salvador_song_grpd['WOC_ratio'] + El_Salvador_song_grpd['rank_pts'] + El_Salvador_song_grpd['streams_ratio'])/3

El_Salvador_song_grpd.columns
El_Salvador_best_songs = El_Salvador_song_grpd[['artist_names', 'track_name', 'Popularity_Score', 'WOC_ratio', 'rank_pts',
       'streams_ratio','streams', 'rank', 'weeks_on_chart',
       'danceability', 'energy', 'loudness', 'speechiness', 'acousticness',
       'valence', 'tempo', 'duration','country']]
El_Salvador_best_songs = El_Salvador_best_songs.sort_values(['Popularity_Score'],ascending=False)
El_Salvador_top_fifty = El_Salvador_best_songs.head(50)
El_Salvador_top_fifty.head(5)
# Out:
#                     artist_names        track_name  Popularity_Score  \
# 129  Bad Bunny, Chencho Corleone   Me Porto Bonito          0.674778
# 126     Bad Bunny, Bomba Estéreo     Ojitos Lindos          0.656555
# 116                    Bad Bunny  Tití Me Preguntó          0.597000
# 103                    Bad Bunny       Moscow Mule          0.582667
# 261                  Danny Ocean         Me Rehúso          0.556075
#
#      WOC_ratio  rank_pts  streams_ratio     streams    rank  weeks_on_chart  \
# 129      0.031  0.993335          1.000  376474.667   1.333             9.0
# 126      0.031  0.991665          0.947  356582.000   1.667             9.0
# 116      0.034  0.983000          0.774  291283.800   3.400            10.0
# 103      0.034  0.978000          0.736  277151.900   4.400            10.0
# 261      1.000  0.588225          0.080   30259.789  82.355           290.0
#
#      danceability  energy  loudness  speechiness  acousticness  valence  \
# 129         0.911   0.712    -5.105        0.082         0.090    0.425
# 126         0.647   0.686    -5.745        0.041         0.080    0.268
# 116         0.650   0.715    -5.198        0.253         0.099    0.187
# 103         0.804   0.674    -5.453        0.033         0.294    0.292
# 261         0.744   0.804    -6.327        0.068         0.023    0.426
#
#        tempo  duration      country
# 129   92.005     179.0  El_Salvador
# 126   79.928     258.0  El_Salvador
# 116  106.672     244.0  El_Salvador
# 103   99.968     246.0  El_Salvador
# 261  104.823     206.0  El_Salvador

# %%
#Estonia Dataframe
# applying groupby() function to
# group the data on team value.
gk = music_df.groupby('country')
  
# Let's print the first entries
# in all the groups formed.
#gk.first()
Estonia_df = gk.get_group('Estonia')

Estonia_song_grpd = Estonia_df.groupby(['artist_names','track_name']).aggregate({'streams':'mean','rank':'mean','weeks_on_chart':'max','danceability':'mean', 'energy':'mean','loudness':'mean',
       'speechiness':'mean', 'acousticness':'mean','valence':'mean', 'tempo':'mean', 'duration':'mean'}).round(3)
Estonia_song_grpd = Estonia_song_grpd.reset_index() 
Estonia_song_grpd['country'] = 'Estonia'
       
Estonia_song_grpd.sort_values(['weeks_on_chart'],ascending=False)

x= Estonia_song_grpd['weeks_on_chart'].max()
Estonia_song_grpd['WOC_ratio'] = Estonia_song_grpd['weeks_on_chart'].div(x).round(3)
Estonia_song_grpd.head(5)

Estonia_song_grpd['rank'].max()
rank_pts = []
for row in Estonia_song_grpd['rank']:
    rank_pts.append((100 - (row * .5))/100)

Estonia_song_grpd['rank_pts'] = rank_pts
Estonia_song_grpd.head(5)

Estonia_song_grpd.sort_values(['streams'],ascending=False)
y = Estonia_song_grpd['streams'].max()
Estonia_song_grpd['streams_ratio'] = Estonia_song_grpd['streams'].div(y).round(3)
Estonia_song_grpd.sort_values(['streams_ratio'],ascending=False)

Estonia_song_grpd['Popularity_Score'] = (Estonia_song_grpd['WOC_ratio'] + Estonia_song_grpd['rank_pts'] + Estonia_song_grpd['streams_ratio'])/3

Estonia_song_grpd.columns
Estonia_best_songs = Estonia_song_grpd[['artist_names', 'track_name', 'Popularity_Score', 'WOC_ratio', 'rank_pts',
       'streams_ratio','streams', 'rank', 'weeks_on_chart',
       'danceability', 'energy', 'loudness', 'speechiness', 'acousticness',
       'valence', 'tempo', 'duration','country']]
Estonia_best_songs = Estonia_best_songs.sort_values(['Popularity_Score'],ascending=False)
Estonia_top_fifty = Estonia_best_songs.head(50)
Estonia_top_fifty.head(5)
# Out:
#       artist_names                                         track_name  \
# 513   Harry Styles                                          As It Was
# 712      Kate Bush  Running Up That Hill (A Deal With God) - 2018 ...
# 108     Arco, Mose                                            mcDrive
# 27        5MIINUST                                              vamos
# 490  Glass Animals                                         Heat Waves
#
#      Popularity_Score  WOC_ratio  rank_pts  streams_ratio    streams   rank  \
# 513          0.682222      0.058  0.988665          1.000  44316.067  2.267
# 712          0.654285      0.027  0.992855          0.943  41771.571  1.429
# 108          0.639333      0.004  0.985000          0.929  41176.000  3.000
# 27           0.605667      0.016  0.990000          0.811  35960.250  2.000
# 490          0.586588      0.329  0.952765          0.478  21175.539  9.447
#
#      weeks_on_chart  danceability  energy  loudness  speechiness  \
# 513            15.0         0.520   0.731    -5.338        0.056
# 712             7.0         0.629   0.547   -13.123        0.055
# 108             1.0         0.738   0.636    -6.204        0.046
# 27              4.0         0.692   0.893    -4.803        0.033
# 490            85.0         0.761   0.525    -6.900        0.094
#
#      acousticness  valence    tempo  duration  country
# 513         0.342    0.662  173.930     167.0  Estonia
# 712         0.720    0.197  108.375     299.0  Estonia
# 108         0.061    0.507  115.062     177.0  Estonia
# 27          0.021    0.773  119.929     199.0  Estonia
# 490         0.440    0.531   80.870     239.0  Estonia

# %%
#Finland Dataframe
# applying groupby() function to
# group the data on team value.
gk = music_df.groupby('country')
  
# Let's print the first entries
# in all the groups formed.
#gk.first()
Finland_df = gk.get_group('Finland')

Finland_song_grpd = Finland_df.groupby(['artist_names','track_name']).aggregate({'streams':'mean','rank':'mean','weeks_on_chart':'max','danceability':'mean', 'energy':'mean','loudness':'mean',
       'speechiness':'mean', 'acousticness':'mean','valence':'mean', 'tempo':'mean', 'duration':'mean'}).round(3)
Finland_song_grpd = Finland_song_grpd.reset_index() 
Finland_song_grpd['country'] = 'Finland'
       
Finland_song_grpd.sort_values(['weeks_on_chart'],ascending=False)

x= Finland_song_grpd['weeks_on_chart'].max()
Finland_song_grpd['WOC_ratio'] = Finland_song_grpd['weeks_on_chart'].div(x).round(3)
Finland_song_grpd.head(5)

Finland_song_grpd['rank'].max()
rank_pts = []
for row in Finland_song_grpd['rank']:
    rank_pts.append((100 - (row * .5))/100)

Finland_song_grpd['rank_pts'] = rank_pts
Finland_song_grpd.head(5)

Finland_song_grpd.sort_values(['streams'],ascending=False)
y = Finland_song_grpd['streams'].max()
Finland_song_grpd['streams_ratio'] = Finland_song_grpd['streams'].div(y).round(3)
Finland_song_grpd.sort_values(['streams_ratio'],ascending=False)

Finland_song_grpd['Popularity_Score'] = (Finland_song_grpd['WOC_ratio'] + Finland_song_grpd['rank_pts'] + Finland_song_grpd['streams_ratio'])/3

Finland_song_grpd.columns
Finland_best_songs = Finland_song_grpd[['artist_names', 'track_name', 'Popularity_Score', 'WOC_ratio', 'rank_pts',
       'streams_ratio','streams', 'rank', 'weeks_on_chart',
       'danceability', 'energy', 'loudness', 'speechiness', 'acousticness',
       'valence', 'tempo', 'duration','country']]
Finland_best_songs = Finland_best_songs.sort_values(['Popularity_Score'],ascending=False)
Finland_top_fifty = Finland_best_songs.head(50)
Finland_top_fifty.head(5)
# Out:
#                       artist_names           track_name  Popularity_Score  \
# 764   Isac Elliot, william, Cledos                20min          0.668667
# 793                            JVG            Amatimies          0.641363
# 1580                       Sexmane         Chillaa veli          0.604333
# 643           Gettomasa, Van Hegen  Shamppanjadieetillä          0.585095
# 513                        El Migu            Erilainen          0.581417
#
#       WOC_ratio  rank_pts  streams_ratio     streams   rank  weeks_on_chart  \
# 764       0.020  0.986000          1.000  732931.200  2.800             5.0
# 793       0.044  0.989090          0.891  653033.727  2.182            11.0
# 1580      0.004  0.995000          0.814  596390.000  1.000             1.0
# 643       0.028  0.979285          0.748  548030.429  4.143             7.0
# 513       0.032  0.976250          0.736  539218.250  4.750             8.0
#
#       danceability  energy  loudness  speechiness  acousticness  valence  \
# 764          0.674   0.718    -7.219        0.095         0.172    0.781
# 793          0.871   0.687    -4.417        0.155         0.072    0.586
# 1580         0.799   0.632    -5.036        0.222         0.191    0.829
# 643          0.862   0.532    -5.765        0.086         0.210    0.453
# 513          0.644   0.631    -6.215        0.081         0.524    0.646
#
#         tempo  duration  country
# 764   120.057     204.0  Finland
# 793   115.963     122.0  Finland
# 1580  160.007     171.0  Finland
# 643   102.017     155.0  Finland
# 513   175.895     166.0  Finland

# %%
#France Dataframe
# applying groupby() function to
# group the data on team value.
gk = music_df.groupby('country')
  
# Let's print the first entries
# in all the groups formed.
#gk.first()
France_df = gk.get_group('France')

France_song_grpd = France_df.groupby(['artist_names','track_name']).aggregate({'streams':'mean','rank':'mean','weeks_on_chart':'max','danceability':'mean', 'energy':'mean','loudness':'mean',
       'speechiness':'mean', 'acousticness':'mean','valence':'mean', 'tempo':'mean', 'duration':'mean'}).round(3)
France_song_grpd = France_song_grpd.reset_index() 
France_song_grpd['country'] = 'France'
       
France_song_grpd.sort_values(['weeks_on_chart'],ascending=False)

x= France_song_grpd['weeks_on_chart'].max()
France_song_grpd['WOC_ratio'] = France_song_grpd['weeks_on_chart'].div(x).round(3)
France_song_grpd.head(5)

France_song_grpd['rank'].max()
rank_pts = []
for row in France_song_grpd['rank']:
    rank_pts.append((100 - (row * .5))/100)

France_song_grpd['rank_pts'] = rank_pts
France_song_grpd.head(5)

France_song_grpd.sort_values(['streams'],ascending=False)
y = France_song_grpd['streams'].max()
France_song_grpd['streams_ratio'] = France_song_grpd['streams'].div(y).round(3)
France_song_grpd.sort_values(['streams_ratio'],ascending=False)

France_song_grpd['Popularity_Score'] = (France_song_grpd['WOC_ratio'] + France_song_grpd['rank_pts'] + France_song_grpd['streams_ratio'])/3

France_song_grpd.columns
France_best_songs = France_song_grpd[['artist_names', 'track_name', 'Popularity_Score', 'WOC_ratio', 'rank_pts',
       'streams_ratio','streams', 'rank', 'weeks_on_chart',
       'danceability', 'energy', 'loudness', 'speechiness', 'acousticness',
       'valence', 'tempo', 'duration','country']]
France_best_songs = France_best_songs.sort_values(['Popularity_Score'],ascending=False)
France_top_fifty = France_best_songs.head(50)
France_top_fifty.head(5)
# Out:
#             artist_names                         track_name  Popularity_Score  \
# 32   Alonzo, Ninho, Naps  TOUT VA BIEN (feat. Ninho & Naps)          0.679333
# 624                Ninho                  La vie qu'on mène          0.608555
# 597                 Naps                        La kiffance          0.606222
# 622                Ninho                               Jefe          0.565583
# 909    ZEG P, Hamza, SCH                            FADE UP          0.558222
#
#      WOC_ratio  rank_pts  streams_ratio      streams    rank  weeks_on_chart  \
# 32       0.046  0.992000          1.000  3088237.600   1.600             8.0
# 624      0.926  0.711665          0.188   580534.778  57.667           162.0
# 597      0.349  0.936665          0.533  1644797.667  12.667            61.0
# 622      0.120  0.983750          0.593  1832679.250   3.250            21.0
# 909      0.017  0.976665          0.681  2102974.333   4.667             3.0
#
#      danceability  energy  loudness  speechiness  acousticness  valence  \
# 32          0.660   0.720    -5.874        0.075         0.301    0.628
# 624         0.800   0.756    -4.400        0.037         0.687    0.456
# 597         0.805   0.637    -6.515        0.087         0.228    0.678
# 622         0.648   0.599    -8.611        0.080         0.474    0.213
# 909         0.758   0.599    -5.990        0.088         0.570    0.557
#
#        tempo  duration country
# 32    99.937     193.0  France
# 624  113.204     193.0  France
# 597  140.045     179.0  France
# 622  120.985     178.0  France
# 909  129.960     219.0  France

# %%
#Germany Dataframe
# applying groupby() function to
# group the data on team value.
gk = music_df.groupby('country')
  
# Let's print the first entries
# in all the groups formed.
#gk.first()
Germany_df = gk.get_group('Germany')

Germany_song_grpd = Germany_df.groupby(['artist_names','track_name']).aggregate({'streams':'mean','rank':'mean','weeks_on_chart':'max','danceability':'mean', 'energy':'mean','loudness':'mean',
       'speechiness':'mean', 'acousticness':'mean','valence':'mean', 'tempo':'mean', 'duration':'mean'}).round(3)
Germany_song_grpd = Germany_song_grpd.reset_index() 
Germany_song_grpd['country'] = 'Germany'
       
Germany_song_grpd.sort_values(['weeks_on_chart'],ascending=False)

x= Germany_song_grpd['weeks_on_chart'].max()
Germany_song_grpd['WOC_ratio'] = Germany_song_grpd['weeks_on_chart'].div(x).round(3)
Germany_song_grpd.head(5)

Germany_song_grpd['rank'].max()
rank_pts = []
for row in Germany_song_grpd['rank']:
    rank_pts.append((100 - (row * .5))/100)

Germany_song_grpd['rank_pts'] = rank_pts
Germany_song_grpd.head(5)

Germany_song_grpd.sort_values(['streams'],ascending=False)
y = Germany_song_grpd['streams'].max()
Germany_song_grpd['streams_ratio'] = Germany_song_grpd['streams'].div(y).round(3)
Germany_song_grpd.sort_values(['streams_ratio'],ascending=False)

Germany_song_grpd['Popularity_Score'] = (Germany_song_grpd['WOC_ratio'] + Germany_song_grpd['rank_pts'] + Germany_song_grpd['streams_ratio'])/3

Germany_song_grpd.columns
Germany_best_songs = Germany_song_grpd[['artist_names', 'track_name', 'Popularity_Score', 'WOC_ratio', 'rank_pts',
       'streams_ratio','streams', 'rank', 'weeks_on_chart',
       'danceability', 'energy', 'loudness', 'speechiness', 'acousticness',
       'valence', 'tempo', 'duration','country']]
Germany_best_songs = Germany_best_songs.sort_values(['Popularity_Score'],ascending=False)
Germany_top_fifty = Germany_best_songs.head(50)
Germany_top_fifty.head(5)
# Out:
#                  artist_names      track_name  Popularity_Score  WOC_ratio  \
# 841                   Luciano  Beautiful Girl          0.677637      0.042
# 1072                 Pashanim   Kleiner Prinz          0.582667      0.004
# 932    Miksu / Macloud, t-low       Sehnsucht          0.537583      0.058
# 318         DJ Robin, Schürze           Layla          0.536333      0.023
# 590   Ion Miles, SiraOne, BHZ        Powerade          0.530833      0.031
#
#       rank_pts  streams_ratio      streams   rank  weeks_on_chart  \
# 841    0.99091          1.000  5103902.273  1.818            11.0
# 1072   0.98500          0.759  3872073.000  3.000             1.0
# 932    0.98375          0.571  2914775.250  3.250            15.0
# 318    0.98000          0.606  3093240.000  4.000             6.0
# 590    0.98250          0.579  2954296.500  3.500             8.0
#
#       danceability  energy  loudness  speechiness  acousticness  valence  \
# 841          0.839   0.412    -8.816        0.094         0.287    0.607
# 1072         0.879   0.611    -7.057        0.272         0.114    0.589
# 932          0.804   0.645    -7.069        0.077         0.642    0.912
# 318          0.442   0.923    -2.921        0.069         0.001    0.398
# 590          0.890   0.720    -5.202        0.073         0.193    0.935
#
#         tempo  duration  country
# 841   139.901     179.0  Germany
# 1072   95.010     148.0  Germany
# 932   142.090     153.0  Germany
# 318   140.081     185.0  Germany
# 590   150.090     142.0  Germany
